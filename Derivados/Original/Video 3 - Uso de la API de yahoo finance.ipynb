# %% [markdown]
# # Video 3 - yahoo finance API yfinance

# %% [markdown]
# Modulo yfinance para Yahoo Finance

# %%
### Importo los modulos

from data_nyse import *

import yfinance as yf
import datetime

# %% [markdown]
# ## API Yahoo finance

# %% [markdown]
# Modulos necesarios
#
# data_nyse (en webcampus) ;
#
# pandas,
#
# matplotlib,
#
# datetime,
#
# yfinance, (yfinance-0.1.63 - tuve que actualizar reicentemente)
#
# sys,
#
# Instalarlos con Anaconda, comando Conda o comando pip install
#
#
# urllib.requestatexit
# datetime
# dateutil
#
# import tda
# json
# selenium, webdriver

# %% [markdown]
# ## Queremos emular lo que hicimos para BYMA

# %%
### Metodo para el web scraping
panel_yahoo_GGAL = obtener_opciones_yahoo_finance('GGAL')
panel_yahoo_GGAL
# Out:
#         contractSymbol       lastTradeDate  strike  lastPrice    bid    ask  \
# 0  GGAL210820C00005000 2021-06-25 15:09:02     5.0       4.30   3.00   3.30
# 1  GGAL210820C00007500 2021-07-16 18:14:14     7.5       0.80   0.80   0.95
# 2  GGAL210820C00010000 2021-07-13 19:26:30    10.0       0.10   0.05   0.15
# 3  GGAL210820C00012500 2021-06-23 17:18:27    12.5       0.10   0.00   0.75
# 0  GGAL211015C00005000 2021-06-08 14:49:02     5.0       5.10   3.10   3.30
# 1  GGAL211015C00007500 2021-07-15 18:35:14     7.5       1.23   1.15   1.50
# 2  GGAL211015C00010000 2021-07-16 16:39:52    10.0       0.30   0.25   0.40
# 3  GGAL211015C00012500 2021-07-16 16:39:52    12.5       0.04   0.00   0.45
# 4  GGAL211015C00015000 2021-07-09 15:51:34    15.0       0.10   0.00   0.30
# 0  GGAL220121C00002500 2021-07-08 18:27:09     2.5       5.70   5.40   6.00
# 1  GGAL220121C00005000 2021-07-12 17:44:38     5.0       3.60   3.20   3.60
# 2  GGAL220121C00007500 2021-07-14 19:10:22     7.5       1.55   1.40   1.65
# 3  GGAL220121C00010000 2021-07-16 16:04:51    10.0       0.57   0.50   0.70
# 4  GGAL220121C00012500 2021-07-16 14:20:22    12.5       0.20   0.15   0.35
# 5  GGAL220121C00015000 2021-07-15 16:24:40    15.0       0.10   0.00   0.15
# 6  GGAL220121C00017500 2021-07-07 18:38:01    17.5       0.07   0.05   0.20
# 7  GGAL220121C00020000 2021-06-07 17:50:33    20.0       0.10   0.05   0.50
# 8  GGAL220121C00022500 2021-06-25 17:15:02    22.5       0.05   0.00   0.85
# 0  GGAL230120C00002500 2021-06-03 14:04:02     2.5       7.25   4.30   7.50
# 1  GGAL230120C00005000 2021-07-16 18:58:52     5.0       3.77   1.70   4.60
# 2  GGAL230120C00007500 2021-07-14 16:57:06     7.5       2.65   2.00   4.50
# 3  GGAL230120C00010000 2021-07-16 19:53:03    10.0       1.45   1.30   1.60
# 4  GGAL230120C00012500 2021-07-15 16:27:58    12.5       0.95   0.30   1.10
# 5  GGAL230120C00015000 2021-07-14 18:41:20    15.0       0.65   0.60   0.80
# 6  GGAL230120C00017500 2021-07-16 19:48:14    17.5       0.55   0.35   0.55
# 7      REGULAR      USD   GGAL  8.18
# 0      REGULAR      USD   GGAL  8.18
# 1      REGULAR      USD   GGAL  8.18
# 2      REGULAR      USD   GGAL  8.18
# 0      REGULAR      USD   GGAL  8.18
# 1      REGULAR      USD   GGAL  8.18
# 2      REGULAR      USD   GGAL  8.18
# 3      REGULAR      USD   GGAL  8.18
# 4      REGULAR      USD   GGAL  8.18
# 0      REGULAR      USD   GGAL  8.18
# 1      REGULAR      USD   GGAL  8.18
# 2      REGULAR      USD   GGAL  8.18
# 3      REGULAR      USD   GGAL  8.18
# 4      REGULAR      USD   GGAL  8.18
# 5      REGULAR      USD   GGAL  8.18
# 6      REGULAR      USD   GGAL  8.18
# 7      REGULAR      USD   GGAL  8.18
# 8      REGULAR      USD   GGAL  8.18
# 0      REGULAR      USD   GGAL  8.18
# 1      REGULAR      USD   GGAL  8.18
# 2      REGULAR      USD   GGAL  8.18
# 3      REGULAR      USD   GGAL  8.18
# 4      REGULAR      USD   GGAL  8.18
# 5      REGULAR      USD   GGAL  8.18
# 6      REGULAR      USD   GGAL  8.18
# 7      REGULAR      USD   GGAL  8.18

# %% [markdown]
# #### Notar que este clean incluye mas columnas que no estaban en la version de byma

# %%
panel_ociones_GGAL_nyse_clean = obtener_panel_opciones_nyse('GGAL', True)
panel_ociones_GGAL_nyse_clean
# Out:
#                 Especie Ticker  Spot CallPut  Strike  TTM   Last  Moneyness  \
# 0   GGAL210820C00005000   GGAL  8.18       C     5.0   34   4.30   1.636000
# 1   GGAL210820C00007500   GGAL  8.18       C     7.5   34   0.80   1.090667
# 2   GGAL210820P00007500   GGAL  8.18       P     7.5   34   0.25   1.090667
# 3   GGAL210820C00010000   GGAL  8.18       C    10.0   34   0.10   0.818000
# 4   GGAL210820P00010000   GGAL  8.18       P    10.0   34   1.90   0.818000
# 5   GGAL210820C00012500   GGAL  8.18       C    12.5   34   0.10   0.654400
# 6   GGAL210820P00012500   GGAL  8.18       P    12.5   34   4.00   0.654400
# 7   GGAL211015P00002500   GGAL  8.18       P     2.5   90   0.25   3.272000
# 8   GGAL211015C00005000   GGAL  8.18       C     5.0   90   5.10   1.636000
# 9   GGAL211015P00005000   GGAL  8.18       P     5.0   90   0.10   1.636000
# 10  GGAL211015C00007500   GGAL  8.18       C     7.5   90   1.23   1.090667
# 11  GGAL211015P00007500   GGAL  8.18       P     7.5   90   0.50   1.090667
# 12  GGAL211015C00010000   GGAL  8.18       C    10.0   90   0.30   0.818000
# 13  GGAL211015P00010000   GGAL  8.18       P    10.0   90   1.95   0.818000
# 14  GGAL211015C00012500   GGAL  8.18       C    12.5   90   0.04   0.654400
# 15  GGAL211015P00012500   GGAL  8.18       P    12.5   90   2.80   0.654400
# 16  GGAL211015C00015000   GGAL  8.18       C    15.0   90   0.10   0.545333
# 17  GGAL220121C00002500   GGAL  8.18       C     2.5  188   5.70   3.272000
# 18  GGAL220121P00002500   GGAL  8.18       P     2.5  188   0.05   3.272000
# 19  GGAL220121C00005000   GGAL  8.18       C     5.0  188   3.60   1.636000
# 14           0.734378   0.00   0.45
# 15           0.689456   3.80   4.50
# 16           0.837892   0.00   0.30
# 17           0.812502   5.40   6.00
# 18           0.953125   0.00   0.10
# 19           0.648441   3.20   3.60
# 20           0.654300   0.00   0.45
# 21           0.515630   1.40   1.65
# 22           0.518071   0.80   0.90
# 23           0.507817   0.50   0.70
# 24           0.533208   2.10   2.85
# 25           0.526372   0.15   0.35
# 26           0.513677   4.40   4.70
# 27           0.500005   0.00   0.15
# 28           0.749026   6.50   7.20
# 29           0.656253   0.05   0.20
# 30           0.000010   0.00   0.00
# 31           0.876954   0.05   0.50
# 32           0.880861  11.10  12.10
# 33           1.060552   0.00   0.85
# 34           1.489260  14.20  16.90
# 35           0.791018   4.30   7.50
# 36           0.679691   0.00   0.25
# 37           0.901368   1.70   4.60
# 38           0.719729   0.40   1.55
# 39           0.782229   2.00   4.50
# 40           0.562993   0.30   1.80
# 41           0.512700   1.30   1.60
# 42           0.570317   1.40   3.50
# 43           0.557133   0.30   1.10
# 44           0.590824   3.60   7.50
# 45           0.540044   0.60   0.80
# 46           0.578129   6.00   9.30
# 47           0.528813   0.35   0.55
# 48           0.620121   8.00  12.10
# 49           0.544926   0.10   0.35
# 50           1.050298  11.50  16.40

# %% [markdown]
# ## Veamos lo que hace

# %%
ticker = 'GGAL'
ggal = yf.Ticker(ticker)

#Data es un objeto
# ggal.info contiene informacion (mucha) del activo en un diccionario

ggal.info
# Out:
# {'zip': '1038',
#  'sector': 'Financial Services',
#  'fullTimeEmployees': 9271,
#  'longBusinessSummary': "Grupo Financiero Galicia S.A., a financial services holding company, provides various financial products and services to individuals and companies in Argentina. The company operates through Banks, Ecosistema NaranjaX, Insurance, and Other Businesses segments. The company's products and services cover savings, current, and checking accounts; personal loans; express and mortgage loans; credit and debit cards; and online banking services. It also offers financing products and services; consumer finance services; electronic check products and services; global custody services; Fima funds; financial and stock market services to individuals, companies, and financial institutions; foreign trade services; and capital market and investment banking products that include debt securities, short-term securities, letters, and financial trusts. In addition, the company provides home and life, and pet insurance, as well as technical insurance with multi-risk coverage for companies. As of December 31, 2020, it had 326 full service banking branches; 1,013 ATMs; and 1,095 self-service terminals. Grupo Financiero Galicia S.A. was founded in 1905 and is based in Buenos Aires, Argentina.",
#  'city': 'Buenos Aires',
#  'phone': '54 11 4343 7528',
#  'country': 'Argentina',
#  'companyOfficers': [],
#  'website': 'http://www.gfgsa.com',
#  'maxAge': 1,
#  'address1': 'Teniente General Juan D. PerOn 430',
#  'fax': '54 11 4343 7528',
#  'industry': 'Banks—Regional',
#  'address2': '25th Floor',
#  'ebitdaMargins': 0,
#  'profitMargins': 0.09575,
#  'grossMargins': 0,
#  'operatingCashflow': 121879674880,
#  'revenueGrowth': -0.095,
#  'operatingMargins': 0.19636999,
#  'ebitda': None,
#  'targetLowPrice': 5,
#  'recommendationKey': 'underperform',
#  'grossProfits': 180556365000,
#  'freeCashflow': None,
#  'targetMedianPrice': 8,
#  'currentPrice': 8.18,
#  'earningsGrowth': -0.816,
#  'currentRatio': None,
#  'returnOnAssets': 0.01774,
#  'numberOfAnalystOpinions': 7,
#  'targetMeanPrice': 7.71,
#  'debtToEquity': None,
#  'returnOnEquity': 0.10334,
#  'targetHighPrice': 9,
#  'totalCash': 313328861184,
#  'totalDebt': 141572751360,
#  'totalRevenue': 180650786816,
#  'totalCashPerShare': 2124.707,
#  'financialCurrency': 'ARS',
#  'revenuePerShare': 1241.82,
#  'quickRatio': None,
#  'recommendationMean': 3.6,
#  'exchange': 'NMS',
#  'shortName': 'Grupo Financiero Galicia S.A.',
#  'longName': 'Grupo Financiero Galicia S.A.',
#  'exchangeTimezoneName': 'America/New_York',
#  'exchangeTimezoneShortName': 'EDT',
#  'isEsgPopulated': False,
#  'gmtOffSetMilliseconds': '-14400000',
#  'quoteType': 'EQUITY',
#  'symbol': 'GGAL',
#  'messageBoardId': 'finmb_1532718',
#  'market': 'us_market',
#  'annualHoldingsTurnover': None,
#  'enterpriseToRevenue': -0.944,
#  'beta3Year': None,
#  'enterpriseToEbitda': None,
#  '52WeekChange': -0.24885213,
#  'morningStarRiskRating': None,
#  'forwardEps': 2.56,
#  'revenueQuarterlyGrowth': None,
#  'sharesOutstanding': 147468992,
#  'fundInceptionDate': None,
#  'annualReportExpenseRatio': None,
#  'totalAssets': None,
#  'bookValue': 1392.94,
#  'sharesShort': 1024840,
#  'sharesPercentSharesOut': 0.0069,
#  'fundFamily': None,
#  'lastFiscalYearEnd': 1609372800,
#  'heldPercentInstitutions': 0.08422,
#  'netIncomeToCommon': 17297162240,
#  'trailingEps': 1.24,
#  'lastDividendValue': 0.064,
#  'SandP52WeekChange': 0.3306805,
#  'priceToBook': 0.0058724717,
#  'heldPercentInsiders': 0.12616,
#  'nextFiscalYearEnd': 1672444800,
#  'yield': None,
#  'mostRecentQuarter': 1617148800,
#  'shortRatio': 1,
#  'sharesShortPreviousMonthDate': 1622160000,
#  'floatShares': 81877854,
#  'beta': 2.565116,
#  'enterpriseValue': -170524737536,
#  'priceHint': 2,
#  'threeYearAverageReturn': None,
#  'lastSplitDate': None,
#  'lastSplitFactor': None,
#  'legalType': None,
#  'lastDividendDate': 1620950400,
#  'morningStarOverallRating': None,
#  'earningsQuarterlyGrowth': -0.81,
#  'priceToSalesTrailing12Months': 0.012046305,
#  'dateShortInterest': 1625011200,
#  'pegRatio': -0.11,
#  'ytdReturn': None,
#  'forwardPE': 3.1953127,
#  'lastCapGain': None,
#  'shortPercentOfFloat': None,
#  'sharesShortPriorMonth': 996041,
#  'impliedSharesOutstanding': None,
#  'category': None,
#  'fiveYearAverageReturn': None,
#  'previousClose': 8.35,
#  'regularMarketOpen': 8.35,
#  'twoHundredDayAverage': 8.193261,
#  'trailingAnnualDividendYield': 0.1217964,
#  'payoutRatio': 0.033800002,
#  'volume24Hr': None,
#  'regularMarketDayHigh': 8.38,
#  'navPrice': None,
#  'averageDailyVolume10Day': 515187,
#  'regularMarketPreviousClose': 8.35,
#  'fiftyDayAverage': 9.206765,
#  'trailingAnnualDividendRate': 1.017,
#  'open': 8.35,
#  'toCurrency': None,
#  'averageVolume10days': 515187,
#  'expireDate': None,
#  'algorithm': None,
#  'dividendRate': 0.06,
#  'exDividendDate': 1620950400,
#  'circulatingSupply': None,
#  'startDate': None,
#  'regularMarketDayLow': 8.11,
#  'currency': 'USD',
#  'trailingPE': 6.5967746,
#  'regularMarketVolume': 386923,
#  'lastMarket': None,
#  'maxSupply': None,
#  'openInterest': None,
#  'marketCap': 2176174592,
#  'volumeAllCurrencies': None,
#  'strikePrice': None,
#  'averageVolume': 779623,
#  'dayLow': 8.11,
#  'ask': 8.18,
#  'askSize': 4000,
#  'volume': 386923,
#  'fiftyTwoWeekHigh': 14.94,
#  'fromCurrency': None,
#  'fiveYearAvgDividendYield': None,
#  'fiftyTwoWeekLow': 5.86,
#  'bid': 8.04,
#  'tradeable': False,
#  'dividendYield': 0.0077,
#  'bidSize': 1400,
#  'dayHigh': 8.38,
#  'regularMarketPrice': 8.18,
#  'logo_url': 'https://logo.clearbit.com/gfgsa.com'}

# %% [markdown]
# ### data.history va a contener la informacion historica. Por lo pronto, podemos obtener el precio

# %%
# Spot price

hist = ggal.history()

hist
# Out:
#              Open   High   Low  Close   Volume  Dividends  Stock Splits
# Date
# 2021-06-17  10.16  10.33  9.89   9.91   573300          0             0
# 2021-06-18   9.85   9.87  9.53   9.67  1276800          0             0
# 2021-06-21   9.77   9.77  9.45   9.45   362000          0             0
# 2021-06-22   9.50   9.92  9.32   9.74   731100          0             0
# 2021-06-23   9.82  10.03  9.58   9.58   645400          0             0
# 2021-06-24   9.58   9.66  9.47   9.54   305700          0             0
# 2021-06-25   9.23   9.32  8.84   9.20  1450600          0             0
# 2021-06-28   9.48   9.54  9.06   9.16   859800          0             0
# 2021-06-29   9.18   9.19  8.66   8.80  1063600          0             0
# 2021-06-30   8.75   8.82  8.53   8.62   700000          0             0
# 2021-07-01   8.62   8.69  8.40   8.50   869100          0             0
# 2021-07-02   8.51   8.60  8.31   8.53   782700          0             0
# 2021-07-06   8.59   8.64  8.25   8.31   709200          0             0
# 2021-07-07   8.25   8.38  8.17   8.30   751500          0             0
# 2021-07-08   8.25   8.25  8.09   8.13   503400          0             0
# 2021-07-09   8.17   8.31  8.12   8.20   240700          0             0
# 2021-07-12   8.14   8.61  8.10   8.58   506300          0             0
# 2021-07-13   8.59   8.59  8.33   8.50   607600          0             0
# 2021-07-14   8.41   8.67  8.41   8.54   641200          0             0
# 2021-07-15   8.49   8.58  8.32   8.35   472900          0             0
# 2021-07-16   8.35   8.38  8.11   8.18   397900          0             0

# %%
spot = hist.tail(1)['Close'].iloc[0]
spot
# Out:
# 8.180000305175781

# %%
# Vencimientos de opciones
vencimientos = ggal.options

vencimientos
# Out:
# ('2021-08-20', '2021-10-15', '2022-01-21', '2023-01-20')

# %%
calls_primer_vencimiento = ggal.option_chain(vencimientos[0])[0]

calls_primer_vencimiento
# Out:
#         contractSymbol       lastTradeDate  strike  lastPrice   bid   ask  \
# 0  GGAL210820C00005000 2021-06-25 15:09:02     5.0        4.3  3.00  3.30
# 1  GGAL210820C00007500 2021-07-16 18:14:14     7.5        0.8  0.80  0.95
# 2  GGAL210820C00010000 2021-07-13 19:26:30    10.0        0.1  0.05  0.15
# 3  GGAL210820C00012500 2021-06-23 17:18:27    12.5        0.1  0.00  0.75
#
#    change  percentChange  volume  openInterest  impliedVolatility  inTheMoney  \
# 0    0.00       0.000000     1.0             1           1.257816        True
# 1   -0.35     -30.434782     4.0            97           0.562504        True
# 2    0.00       0.000000     8.0            36           0.566411       False
# 3    0.00       0.000000     NaN             1           1.400394       False
#
#   contractSize currency
# 0      REGULAR      USD
# 1      REGULAR      USD
# 2      REGULAR      USD
# 3      REGULAR      USD

# %%
puts_primer_vencimiento = ggal.option_chain(vencimientos[0])[1]

puts_primer_vencimiento
# Out:
#         contractSymbol       lastTradeDate  strike  lastPrice  bid   ask  \
# 0  GGAL210820P00007500 2021-07-09 15:13:13     7.5       0.25  0.0  0.55
# 1  GGAL210820P00010000 2021-07-16 19:48:15    10.0       1.90  1.6  1.95
# 2  GGAL210820P00012500 2021-07-02 19:30:41    12.5       4.00  4.2  4.50
#
#    change  percentChange  volume  openInterest  impliedVolatility  inTheMoney  \
# 0    0.00       0.000000       5           141           0.568364       False
# 1    0.19      11.111108       5             4           0.617191        True
# 2    0.00       0.000000      10            10           0.742190        True
#
#   contractSize currency
# 0      REGULAR      USD
# 1      REGULAR      USD
# 2      REGULAR      USD

# %%
# Calls y puts
calls = ggal.option_chain(vencimientos[0])[0]
puts = ggal.option_chain(vencimientos[0])[1]

puts
# Out:
#         contractSymbol       lastTradeDate  strike  lastPrice  bid   ask  \
# 0  GGAL210820P00007500 2021-07-09 15:13:13     7.5       0.25  0.0  0.55
# 1  GGAL210820P00010000 2021-07-16 19:48:15    10.0       1.90  1.6  1.95
# 2  GGAL210820P00012500 2021-07-02 19:30:41    12.5       4.00  4.2  4.50
#
#    change  percentChange  volume  openInterest  impliedVolatility  inTheMoney  \
# 0    0.00       0.000000       5           141           0.568364       False
# 1    0.19      11.111108       5             4           0.617191        True
# 2    0.00       0.000000      10            10           0.742190        True
#
#   contractSize currency
# 0      REGULAR      USD
# 1      REGULAR      USD
# 2      REGULAR      USD

# %% [markdown]
# ### Que hace internamente el metodo??

# %%
#Recorro cada vencimiento disponible y voy tomando calls por un lado y puts por otro
for vencimiento in vencimientos[1:]:
        calls = calls.append(ggal.option_chain(vencimiento)[0])
        puts = puts.append(ggal.option_chain(vencimiento)[1])

        
calls
# Out:
#         contractSymbol       lastTradeDate  strike  lastPrice   bid   ask  \
# 0  GGAL210820C00005000 2021-06-25 15:09:02     5.0       4.30  3.00  3.30
# 1  GGAL210820C00007500 2021-07-16 18:14:14     7.5       0.80  0.80  0.95
# 2  GGAL210820C00010000 2021-07-13 19:26:30    10.0       0.10  0.05  0.15
# 3  GGAL210820C00012500 2021-06-23 17:18:27    12.5       0.10  0.00  0.75
# 0  GGAL211015C00005000 2021-06-08 14:49:02     5.0       5.10  3.10  3.30
# 1  GGAL211015C00007500 2021-07-15 18:35:14     7.5       1.23  1.15  1.50
# 2      REGULAR      USD
# 3      REGULAR      USD
# 4      REGULAR      USD
# 5      REGULAR      USD
# 6      REGULAR      USD
# 7      REGULAR      USD
# 8      REGULAR      USD
# 0      REGULAR      USD
# 1      REGULAR      USD
# 2      REGULAR      USD
# 3      REGULAR      USD
# 4      REGULAR      USD
# 5      REGULAR      USD
# 6      REGULAR      USD
# 7      REGULAR      USD

# %%
# Le agrego dos columnas utiles - Ticker y Spot

panel_opciones['Spot'] = hist.tail(1)['Close'].iloc[0]
panel_opciones['Ticker'] = ticker

panel_opciones.head(10)
# Out:
#         contractSymbol       lastTradeDate  strike  lastPrice   bid   ask  \
# 0  GGAL210820C00005000 2021-06-25 15:09:02     5.0       4.30  3.00  3.30
# 1  GGAL210820C00007500 2021-07-16 18:14:14     7.5       0.80  0.80  0.95
# 2  GGAL210820C00010000 2021-07-13 19:26:30    10.0       0.10  0.05  0.15
# 3  GGAL210820C00012500 2021-06-23 17:18:27    12.5       0.10  0.00  0.75
# 0  GGAL211015C00005000 2021-06-08 14:49:02     5.0       5.10  3.10  3.30
# 1  GGAL211015C00007500 2021-07-15 18:35:14     7.5       1.23  1.15  1.50
# 2  GGAL211015C00010000 2021-07-16 16:39:52    10.0       0.30  0.25  0.40
# 3  GGAL211015C00012500 2021-07-16 16:39:52    12.5       0.04  0.00  0.45
# 4  GGAL211015C00015000 2021-07-09 15:51:34    15.0       0.10  0.00  0.30
# 0  GGAL220121C00002500 2021-07-08 18:27:09     2.5       5.70  5.40  6.00
#
#    change  percentChange  volume  openInterest  impliedVolatility  inTheMoney  \
# 0    0.00       0.000000     1.0             1           1.257816        True
# 1   -0.35     -30.434782     4.0            97           0.562504        True
# 2    0.00       0.000000     8.0            36           0.566411       False
# 3    0.00       0.000000     NaN             1           1.400394       False
# 0    0.00       0.000000     1.0             1           0.523442        True
# 1   -0.07      -5.384611     5.0           297           0.608402        True
# 2   -0.07     -18.918917    20.0          1743           0.542973       False
# 3    0.01      33.333336    10.0          1376           0.734378       False
# 4    0.00       0.000000     5.0           659           0.837892       False
# 0    0.00       0.000000     1.0             1           0.812502        True
#
#   contractSize currency  Spot Ticker
# 0      REGULAR      USD  8.18   GGAL
# 1      REGULAR      USD  8.18   GGAL
# 2      REGULAR      USD  8.18   GGAL
# 3      REGULAR      USD  8.18   GGAL
# 0      REGULAR      USD  8.18   GGAL
# 1      REGULAR      USD  8.18   GGAL
# 2      REGULAR      USD  8.18   GGAL
# 3      REGULAR      USD  8.18   GGAL
# 4      REGULAR      USD  8.18   GGAL
# 0      REGULAR      USD  8.18   GGAL

# %% [markdown]
# ## Del panel de Yahoo crudo a otro con informacion customizada (igual que antes)

# %% [markdown]
# #### *) Agrego columnas utiles

# %%
panel_opciones['Moneyness'] = 0.0
panel_opciones['TTM'] = 0
panel_opciones['CallPut'] = ''
panel_opciones = panel_opciones.reset_index()

panel_opciones.head(5)
# Out:
#    index       contractSymbol       lastTradeDate  strike  lastPrice   bid  \
# 0      0  GGAL210820C00005000 2021-06-25 15:09:02     5.0        4.3  3.00
# 1      1  GGAL210820C00007500 2021-07-16 18:14:14     7.5        0.8  0.80
# 2      2  GGAL210820C00010000 2021-07-13 19:26:30    10.0        0.1  0.05
# 3      3  GGAL210820C00012500 2021-06-23 17:18:27    12.5        0.1  0.00
# 4      0  GGAL211015C00005000 2021-06-08 14:49:02     5.0        5.1  3.10
#
#     ask  change  percentChange  volume  openInterest  impliedVolatility  \
# 0  3.30    0.00       0.000000     1.0             1           1.257816
# 1  0.95   -0.35     -30.434782     4.0            97           0.562504
# 2  0.15    0.00       0.000000     8.0            36           0.566411
# 3  0.75    0.00       0.000000     NaN             1           1.400394
# 4  3.30    0.00       0.000000     1.0             1           0.523442
#
#    inTheMoney contractSize currency  Spot Ticker  Moneyness  TTM CallPut
# 0        True      REGULAR      USD  8.18   GGAL        0.0    0
# 1        True      REGULAR      USD  8.18   GGAL        0.0    0
# 2       False      REGULAR      USD  8.18   GGAL        0.0    0
# 3       False      REGULAR      USD  8.18   GGAL        0.0    0
# 4        True      REGULAR      USD  8.18   GGAL        0.0    0

# %% [markdown]
# #### *) Recorro las filas (1ra como ejemplo)

# %%
idx = panel_opciones.index.values[0]
idx
# Out:
# 0

# %%
panel_opciones.contractSymbol.values[idx][10:11]
# Out:
# 'C'

# %%
callput = panel_opciones.contractSymbol.values[idx][10:11]
panel_opciones['CallPut'].values[idx] = callput

# %%
year = 2000 + int(panel_opciones.contractSymbol.values[idx][4:6])
month = int(panel_opciones.contractSymbol.values[idx][6:8])
day = int(panel_opciones.contractSymbol.values[idx][8:10])

# %%
hoy = datetime.date.today()
expiry_datetime = datetime.date(year, month, day)


expiry_datetime
# Out:
# datetime.date(2021, 8, 20)

# %%
ttm = (expiry_datetime - hoy).days

ttm
# Out:
# 34

# %%
panel_opciones['TTM'].values[idx] = ttm

panel_opciones['Moneyness'].values[idx] = panel_opciones['Spot'].values[idx] / panel_opciones['strike'].values[idx]

# %%
panel_opciones.head(2)
# Out:
#    index       contractSymbol       lastTradeDate  strike  lastPrice  bid  \
# 0      0  GGAL210820C00005000 2021-06-25 15:09:02     5.0        4.3  3.0
# 1      1  GGAL210820C00007500 2021-07-16 18:14:14     7.5        0.8  0.8
#
#     ask  change  percentChange  volume  openInterest  impliedVolatility  \
# 0  3.30    0.00       0.000000     1.0             1           1.257816
# 1  0.95   -0.35     -30.434782     4.0            97           0.562504
#
#    inTheMoney contractSize currency  Spot Ticker  Moneyness  TTM CallPut
# 0        True      REGULAR      USD  8.18   GGAL      1.636   34       C
# 1        True      REGULAR      USD  8.18   GGAL      0.000    0

# %% [markdown]
# #### *) Recorro las filas (las restantes como ejemplo)

# %%
for idx in list(panel_opciones.index.values[1:]):
        year = 2000 + int(panel_opciones.contractSymbol.values[idx][4:6])
        month = int(panel_opciones.contractSymbol.values[idx][6:8])
        day = int(panel_opciones.contractSymbol.values[idx][8:10])
        
        hoy = datetime.date.today()
        expiry_datetime = datetime.date(year, month, day)
        ttm = (expiry_datetime - hoy).days

        panel_opciones['TTM'].values[idx] = ttm
        callput = panel_opciones.contractSymbol.values[idx][10:11]
        panel_opciones['CallPut'].values[idx] = callput
        
panel_opciones.Moneyness = panel_opciones.Spot/ panel_opciones.strike

# %%
panel_opciones.head(10)
# Out:
#    index       contractSymbol       lastTradeDate  strike  lastPrice   bid  \
# 0      0  GGAL210820C00005000 2021-06-25 15:09:02     5.0       4.30  3.00
# 1      1  GGAL210820C00007500 2021-07-16 18:14:14     7.5       0.80  0.80
# 2      2  GGAL210820C00010000 2021-07-13 19:26:30    10.0       0.10  0.05
# 3      3  GGAL210820C00012500 2021-06-23 17:18:27    12.5       0.10  0.00
# 4      0  GGAL211015C00005000 2021-06-08 14:49:02     5.0       5.10  3.10
# 5      1  GGAL211015C00007500 2021-07-15 18:35:14     7.5       1.23  1.15
# 6      2  GGAL211015C00010000 2021-07-16 16:39:52    10.0       0.30  0.25
# 7      3  GGAL211015C00012500 2021-07-16 16:39:52    12.5       0.04  0.00
# 8      4  GGAL211015C00015000 2021-07-09 15:51:34    15.0       0.10  0.00
# 9      0  GGAL220121C00002500 2021-07-08 18:27:09     2.5       5.70  5.40
#
#     ask  change  percentChange  volume  openInterest  impliedVolatility  \
# 0  3.30    0.00       0.000000     1.0             1           1.257816
# 1  0.95   -0.35     -30.434782     4.0            97           0.562504
# 2  0.15    0.00       0.000000     8.0            36           0.566411
# 3  0.75    0.00       0.000000     NaN             1           1.400394
# 4  3.30    0.00       0.000000     1.0             1           0.523442
# 5  1.50   -0.07      -5.384611     5.0           297           0.608402
# 6  0.40   -0.07     -18.918917    20.0          1743           0.542973
# 7  0.45    0.01      33.333336    10.0          1376           0.734378
# 8  0.30    0.00       0.000000     5.0           659           0.837892
# 9  6.00    0.00       0.000000     1.0             1           0.812502
#
#    inTheMoney contractSize currency  Spot Ticker  Moneyness  TTM CallPut
# 0        True      REGULAR      USD  8.18   GGAL   1.636000   34       C
# 1        True      REGULAR      USD  8.18   GGAL   1.090667   34       C
# 2       False      REGULAR      USD  8.18   GGAL   0.818000   34       C
# 3       False      REGULAR      USD  8.18   GGAL   0.654400   34       C
# 4        True      REGULAR      USD  8.18   GGAL   1.636000   90       C
# 5        True      REGULAR      USD  8.18   GGAL   1.090667   90       C
# 6       False      REGULAR      USD  8.18   GGAL   0.818000   90       C
# 7       False      REGULAR      USD  8.18   GGAL   0.654400   90       C
# 8       False      REGULAR      USD  8.18   GGAL   0.545333   90       C
# 9        True      REGULAR      USD  8.18   GGAL   3.272000  188       C

# %% [markdown]
# #### Panel Limpio

# %%
panel_opciones = panel_opciones.rename(
            columns={'lastTradeDate': 'Last_Date', 'contractSymbol': 'Especie', 'strike': 'Strike', 'bid': 'Bid',
                     'ask': 'Ask', 'lastPrice': 'Last'}, inplace=False)

panel_opciones = panel_opciones.sort_values(['TTM', 'Strike', 'CallPut'])

panel_opciones = panel_opciones[['Especie', 'Ticker', 'Spot', 'CallPut', 'Strike', 'TTM', 'Last', 'Bid','Ask','impliedVolatility','Moneyness']]

panel_opciones
# Out:
#                 Especie Ticker  Spot CallPut  Strike  TTM   Last    Bid  \
# 44  GGAL230120P00005000   GGAL  8.18       P     5.0  552   0.57   0.40
# 20  GGAL230120C00007500   GGAL  8.18       C     7.5  552   2.65   2.00
# 45  GGAL230120P00007500   GGAL  8.18       P     7.5  552   1.75   0.30
# 21  GGAL230120C00010000   GGAL  8.18       C    10.0  552   1.45   1.30
# 46  GGAL230120P00010000   GGAL  8.18       P    10.0  552   2.95   1.40
# 22  GGAL230120C00012500   GGAL  8.18       C    12.5  552   0.95   0.30
# 47  GGAL230120P00012500   GGAL  8.18       P    12.5  552   5.00   3.60
# 23  GGAL230120C00015000   GGAL  8.18       C    15.0  552   0.65   0.60
# 48  GGAL230120P00015000   GGAL  8.18       P    15.0  552   6.51   6.00
# 24  GGAL230120C00017500   GGAL  8.18       C    17.5  552   0.55   0.35
# 49  GGAL230120P00017500   GGAL  8.18       P    17.5  552  11.75   8.00
# 25  GGAL230120C00020000   GGAL  8.18       C    20.0  552   0.35   0.10
# 50  GGAL230120P00020000   GGAL  8.18       P    20.0  552  13.93  11.50
#
#       Ask  impliedVolatility  Moneyness
# 0    3.30           1.257816   1.636000
# 1    0.95           0.562504   1.090667
# 26   0.55           0.568364   1.090667
# 2    0.15           0.566411   0.818000
# 27   1.95           0.617191   0.818000
# 3    0.75           1.400394   0.654400
# 28   4.50           0.742190   0.654400
# 29   0.05           1.218754   3.272000
# 4    3.30           0.523442   1.636000
# 30   0.45           0.941407   1.636000
# 5    1.50           0.608402   1.090667
# 31   0.75           0.578129   1.090667
# 6    0.40           0.542973   0.818000
# 32   2.55           0.816408   0.818000
# 7    0.45           0.734378   0.654400
# 33   4.50           0.689456   0.654400
# 8    0.30           0.837892   0.545333
# 9    6.00           0.812502   3.272000
# 34   0.10           0.953125   3.272000
# 10   3.60           0.648441   1.636000
# 35   0.45           0.654300   1.636000
# 11   1.65           0.515630   1.090667
# 36   0.90           0.518071   1.090667
# 12   0.70           0.507817   0.818000
# 37   2.85           0.533208   0.818000
# 13   0.35           0.526372   0.654400
# 38   4.70           0.513677   0.654400
# 14   0.15           0.500005   0.545333
# 39   7.20           0.749026   0.545333
# 15   0.20           0.656253   0.467429
# 40   0.00           0.000010   0.467429
# 16   0.50           0.876954   0.409000
# 41  12.10           0.880861   0.409000
# 17   0.85           1.060552   0.363556
# 42  16.90           1.489260   0.363556
# 18   7.50           0.791018   3.272000
# 43   0.25           0.679691   3.272000
# 19   4.60           0.901368   1.636000
# 44   1.55           0.719729   1.636000
# 20   4.50           0.782229   1.090667
# 45   1.80           0.562993   1.090667
# 21   1.60           0.512700   0.818000
# 46   3.50           0.570317   0.818000
# 22   1.10           0.557133   0.654400
# 47   7.50           0.590824   0.654400
# 23   0.80           0.540044   0.545333
# 48   9.30           0.578129   0.545333
# 24   0.55           0.528813   0.467429
# 49  12.10           0.620121   0.467429
# 25   0.35           0.544926   0.409000
# 50  16.40           1.050298   0.409000

# %%
panel_opciones = panel_opciones.reset_index()
del panel_opciones['index']
panel_opciones

# %% [markdown]
# ## 2) Ploteando los datos

# %% [markdown]
# ### Para cada vencimiento, grafico los strikes

# %%
# NYSE
panel_opciones_ggal_nyse_limpio = obtener_panel_opciones_nyse('GGAL', True)

TTMs = list(set(panel_opciones_ggal_nyse_limpio.TTM.values))
TTMs
# Out:
# [552, 34, 188, 90]

# %%
TTM = 34
panel_opciones_ggal_nyse_limpio[(panel_opciones_ggal_nyse_limpio.TTM == TTM) & (panel_opciones_ggal_nyse_limpio.CallPut == "C")].head(10)
# Out:
#                Especie Ticker  Spot CallPut  Strike  TTM  Last  Moneyness  \
# 0  GGAL210820C00005000   GGAL  8.18       C     5.0   34   4.3   1.636000
# 1  GGAL210820C00007500   GGAL  8.18       C     7.5   34   0.8   1.090667
# 3  GGAL210820C00010000   GGAL  8.18       C    10.0   34   0.1   0.818000
# 5  GGAL210820C00012500   GGAL  8.18       C    12.5   34   0.1   0.654400
#
#    impliedVolatility   Bid   Ask
# 0           1.257816  3.00  3.30
# 1           0.562504  0.80  0.95
# 3           0.566411  0.05  0.15
# 5           1.400394  0.00  0.75

# %%
from matplotlib import pyplot as plt
CP = "C"
for TTM in TTMs[1:2]:
    Ks = panel_opciones_ggal_nyse_limpio[(panel_opciones_ggal_nyse_limpio.TTM == TTM) & (panel_opciones_ggal_nyse_limpio.CallPut == CP)].Strike.values
    precios = panel_opciones_ggal_nyse_limpio[(panel_opciones_ggal_nyse_limpio.TTM == TTM) & (panel_opciones_ggal_nyse_limpio.CallPut == CP)].Last.values
    ## Last VS (B+A)/2
    plt.plot(Ks, precios,'*', label='TTM = '+str(TTM))


plt.legend()

plt.xlabel('Strike')
plt.ylabel('Precio de mercado del Call')
plt.title('Precio de mercado de las opciones Call con respecto al Strike')
    
plt.show()

# %%
CP = "P"
for TTM in TTMs:
    Ks = panel_opciones_ggal_nyse_limpio[(panel_opciones_ggal_nyse_limpio.TTM == TTM) & (panel_opciones_ggal_nyse_limpio.CallPut == CP)].Strike.values
    precios = panel_opciones_ggal_nyse_limpio[(panel_opciones_ggal_nyse_limpio.TTM == TTM) & (panel_opciones_ggal_nyse_limpio.CallPut == CP)].Last.values
    plt.plot(Ks, precios,'*', label='TTM = '+str(TTM))


plt.legend()

plt.xlabel('Strike')
plt.ylabel('Precio de mercado del Call')
plt.title('Precio de mercado de las opciones Call con respecto al Strike')
    
plt.show()

# %% [markdown]
# ### Para cada strike, grafico los TTM

# %%
Ks = list(set(panel_opciones_ggal_nyse_limpio.Strike.values))

Ks
# Out:
# [2.5, 5.0, 7.5, 10.0, 12.5, 15.0, 17.5, 20.0, 22.5]

# %%
from matplotlib import pyplot as plt
CP = "C"
for K in Ks[2:3]:
    TTMs = panel_opciones_ggal_nyse_limpio[(panel_opciones_ggal_nyse_limpio.Strike == K) & (panel_opciones_ggal_nyse_limpio.CallPut == CP)].TTM.values
    precios = panel_opciones_ggal_nyse_limpio[(panel_opciones_ggal_nyse_limpio.Strike == K) & (panel_opciones_ggal_nyse_limpio.CallPut == CP)].Last.values
    if len(TTMs)>1:
        plt.plot(TTMs, precios,'*', label='Strike = '+str(K))

plt.legend()

plt.xlabel('TTM')
plt.ylabel('Precio de mercado del Call')
plt.title('Precio de mercado de las opciones Call con respecto al TTM')
    
plt.show()

# %% [markdown]
# ## Ploteando los datos con un ticker mega liquido

# %%
# NYSE AAPL
ticker = 'TSLA'
panel_opciones_nyse_limpio = obtener_panel_opciones_nyse(ticker, True)

TTMs = list(set(panel_opciones_nyse_limpio.TTM.values))
TTMs.sort()
TTMs
# Out:
# [6, 13, 20, 27, 34, 41, 62, 90, 125, 153, 188, 244, 335, 426, 552, 608, 699]

# %%
from matplotlib import pyplot as plt
CP = "C"
for TTM in TTMs[0:1]:
    Ks = panel_opciones_nyse_limpio[(panel_opciones_nyse_limpio.TTM == TTM) & (panel_opciones_nyse_limpio.CallPut == CP)].Strike.values
    precios = panel_opciones_nyse_limpio[(panel_opciones_nyse_limpio.TTM == TTM) & (panel_opciones_nyse_limpio.CallPut == CP)].Last.values
    plt.plot(Ks, precios, '.',label='TTM = '+str(TTM))


plt.legend()

plt.xlabel('Strike')
plt.ylabel('Precio de mercado del Call')
plt.title('Precio de mercado de las opciones Call con respecto al Strike')
    
plt.show()

# %%
from matplotlib import pyplot as plt
CP = "C"
for TTM in TTMs[5:6]:
    Ks = panel_opciones_nyse_limpio[(panel_opciones_nyse_limpio.TTM == TTM) & (panel_opciones_nyse_limpio.CallPut == CP)].Strike.values
    precios = panel_opciones_nyse_limpio[(panel_opciones_nyse_limpio.TTM == TTM) & (panel_opciones_nyse_limpio.CallPut == CP)].Last.values
    plt.plot(Ks, precios, '.',label='TTM = '+str(TTM))


plt.legend()

plt.xlabel('Strike')
plt.ylabel('Precio de mercado del Call')
plt.title('Precio de mercado de las opciones Call con respecto al Strike')
    
plt.show()

# %%
from matplotlib import pyplot as plt
CP = "C"
for TTM in TTMs[2:5]:
    Ks = panel_opciones_nyse_limpio[(panel_opciones_nyse_limpio.TTM == TTM) & (panel_opciones_nyse_limpio.CallPut == CP)].Strike.values
    precios = panel_opciones_nyse_limpio[(panel_opciones_nyse_limpio.TTM == TTM) & (panel_opciones_nyse_limpio.CallPut == CP)].Last.values
    plt.plot(Ks, precios,'.',label='TTM = '+str(TTM))


plt.legend()

plt.xlabel('Strike')
plt.ylabel('Precio de mercado del Call')
plt.title('Precio de mercado de las opciones Call con respecto al Strike')
    
plt.show()

# %%
from matplotlib import pyplot as plt
CP = "P"
for TTM in TTMs[3:6]:
    Ks = panel_opciones_nyse_limpio[(panel_opciones_nyse_limpio.TTM == TTM) & (panel_opciones_nyse_limpio.CallPut == CP)].Strike.values
    precios = panel_opciones_nyse_limpio[(panel_opciones_nyse_limpio.TTM == TTM) & (panel_opciones_nyse_limpio.CallPut == CP)].Last.values
    plt.plot(Ks, precios, '.',label='TTM = '+str(TTM))


plt.legend()

plt.xlabel('Strike')
plt.ylabel('Precio de mercado del Put')
plt.title('Precio de mercado de las opciones Put con respecto al Strike')
    
plt.show()

# %%
from matplotlib import pyplot as plt
CP = "P"
for TTM in TTMs[10:15]:
    Ks = panel_opciones_nyse_limpio[(panel_opciones_nyse_limpio.TTM == TTM) & (panel_opciones_nyse_limpio.CallPut == CP)].Strike.values
    precios = panel_opciones_nyse_limpio[(panel_opciones_nyse_limpio.TTM == TTM) & (panel_opciones_nyse_limpio.CallPut == CP)].Last.values
    plt.plot(Ks, precios, '.',label='TTM = '+str(TTM))


plt.legend()

plt.xlabel('Strike')
plt.ylabel('Precio de mercado del Put')
plt.title('Precio de mercado de las opciones Put con respecto al Strike')
    
plt.show()

# %%
from matplotlib import pyplot as plt
CP = "P"
for TTM in TTMs[11:17]:
    Ks = panel_opciones_nyse_limpio[(panel_opciones_nyse_limpio.TTM == TTM) & (panel_opciones_nyse_limpio.CallPut == CP)].Strike.values
    precios = panel_opciones_nyse_limpio[(panel_opciones_nyse_limpio.TTM == TTM) & (panel_opciones_nyse_limpio.CallPut == CP)].Last.values
    plt.plot(Ks, precios, '.',label='TTM = '+str(TTM))


plt.legend()

plt.xlabel('Strike')
plt.ylabel('Precio de mercado del Put')
plt.title('Precio de mercado de las opciones Put con respecto al Strike')
    
plt.show()

# %%
Ks = list(set(panel_opciones_nyse_limpio.Strike.values))
Ks.sort()
len(Ks)
# Out:
# 604

# %%
from matplotlib import pyplot as plt
CP = "C"
for K in Ks[363:364]:
    TTMs = panel_opciones_nyse_limpio[(panel_opciones_nyse_limpio.Strike == K) & (panel_opciones_nyse_limpio.CallPut == CP)].TTM.values
    precios = panel_opciones_nyse_limpio[(panel_opciones_nyse_limpio.Strike == K) & (panel_opciones_nyse_limpio.CallPut == CP)].Last.values
    if len(TTMs)>1:
        plt.plot(TTMs, precios,'*', label='Strike = '+str(K))

plt.legend()

plt.xlabel('TTM')
plt.ylabel('Precio de mercado del Call')
plt.title('Precio de mercado de las opciones Call con respecto al TTM')
    
plt.show()

# %%
from matplotlib import pyplot as plt
CP = "P"
for K in Ks[100:]:
    TTMs = panel_opciones_nyse_limpio[(panel_opciones_nyse_limpio.Strike == K) & (panel_opciones_nyse_limpio.CallPut == CP)].Strike.values
    precios = panel_opciones_nyse_limpio[(panel_opciones_nyse_limpio.Strike == K) & (panel_opciones_nyse_limpio.CallPut == CP)].Last.values
    if len(TTMs)>1:
        plt.plot(TTMs, precios,'*', label='Strike = '+str(K))

plt.legend()

plt.xlabel('TTM')
plt.ylabel('Precio de mercado del Put')
plt.title('Precio de mercado de las opciones Put con respecto al TTM')
    
plt.show()

# %% [markdown]
# ## Pasar a Excel

# %%
panel_opciones_ggal_nyse_crudo = obtener_panel_opciones_nyse('GGAL', False)
panel_opciones_ggal_nyse_crudo.to_excel('Clase_2_panel_opciones_ggal_nyse_crudo.xls')

panel_opciones_ggal_nyse_limpio = obtener_panel_opciones_nyse('GGAL', True)
panel_opciones_ggal_nyse_limpio.to_excel('Clase_2_panel_opciones_ggal_nyse_limpio.xls')


panel_opciones_aapl_nyse_limpio = obtener_panel_opciones_nyse('AAPL', True)
panel_opciones_aapl_nyse_limpio.to_excel('Clase_2_panel_opciones_aapl_nyse_limpio.xls')

# %% [markdown]
# ## 3) Payoffs y Estrategias

# %%
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# ### Vanilla Call y Put

# %%
def payoff_call(S,K):
    return np.maximum(S-K,0)

def payoff_put(S,K):
    return np.maximum(K-S,0)

# %%
K=50
S = np.linspace(0,100,50)

# %%
#Grafico la call

plt.plot(S,payoff_call(S, K))
plt.show()

# %%
#Grafico la put
plt.plot(S,payoff_put(S, K))
plt.show()

# %% [markdown]
# ### Forward sintetico y Combo

# %%
def payoff_forwardSintetico(S,K):
    return payoff_call(S,K)-payoff_put(S, K)

def payoff_combo(S,K1,K2):
    return payoff_call(S,K2)-payoff_put(S, K1)

# %%
#Grafico el forward sintetico
plt.plot(S,payoff_forwardSintetico(S, K))
plt.show()

# %%
K1 = 35
K2 = 65

# %%
#Grafico el combo
plt.plot(S,payoff_combo(S, K1,K2))
plt.show()

# %% [markdown]
# ### Spreads

# %%
def payoff_BullCS(S,K1,K2):
    return payoff_call(S,K1)-payoff_call(S, K2)

def payoff_BearCS(S,K1,K2):
    return payoff_call(S,K2)-payoff_call(S, K1)

def payoff_BullPS(S,K1,K2):
    return payoff_put(S,K1)-payoff_put(S, K2)


def payoff_BearPS(S,K1,K2):
    return payoff_put(S,K2)-payoff_put(S, K1)

# %%
#Grafico el Bull Call Spread
plt.plot(S,payoff_BullCS(S, K1, K2))
plt.show()

# %%
#Grafico el Bear Call Spread
plt.plot(S,payoff_BearCS(S, K1, K2))
plt.show()

# %%
#Grafico el Bull Put Spread
plt.plot(S,payoff_BullPS(S, K1, K2))
plt.show()

# %%
#Grafico el Bear Put Spread
plt.plot(S,payoff_BearPS(S, K1, K2))
plt.show()

# %% [markdown]
# ### Butterfly spreads

# %%
def payoff_CButterflyS(S,K1,K2,K3):
    return payoff_call(S,K1)-2*payoff_call(S, K2)+payoff_call(S, K3)

def payoff_PButterflyS(S,K1,K2,K3):
    return payoff_put(S,K1)-2*payoff_put(S, K2)+payoff_put(S, K3)

# %%
K1=35
K2=50
K3=65

# %%
#Grafico el Call Buterfly Spread
plt.plot(S,payoff_CButterflyS(S, K1, K2,K3))
plt.show()

# %%
#Grafico el Put Buterfly Spread
plt.plot(S,payoff_PButterflyS(S, K1, K2,K3))
plt.show()

# %% [markdown]
# ### Straddle y Strangle

# %%
def payoff_straddle(S,K):
    return payoff_call(S,K)+payoff_put(S, K)


def payoff_strangle(S,K1,K2):
    return payoff_call(S,K1)+payoff_put(S, K2)

# %%
K1 = 35
K2 = 65

# %%
#Grafico el Strangle
plt.plot(S,payoff_strangle(S, K1,K2))
plt.show()

# %%
#Grafico el Straddle

plt.plot(S,payoff_straddle(S, K))
plt.show()

# %% [markdown]
# ### Estrategia AD hoc - Iron Condor

# %%
def payoff_iron_condor(S,K1,K2,K3,K4):
    return payoff_put(S,K1)-payoff_put(S, K2)-payoff_call(S,K3)+payoff_call(S,K4)

# %%
K1 = 30
K2 = 45
K3 = 55
K4 = 70

# %%
plt.plot(S,payoff_iron_condor(S, K1,K2,K3,K4))
plt.show()

# %%
#usando el script con los metodos
import payoffs
payoffs.payoff_call(100,50)
