# %% [markdown]
# # Video 2 -  Uso de pyhomebroker

# %% [markdown]
# ### Importo los modulos
#
# *En el video estaban en una carpeta llamada Codigo. Ahora esta todo en una carpeta Python*

# %%
#from data_byma import *
#from utils_opciones_byma import *
from data_byma_homebroker import *

# %% [markdown]
# ## (3) pyhomebroker

# %% [markdown]
# ### pyhomebroker es una a API para conectar a un programa/script/notebook de python al mercado a traves de AlyCs que usen la plataforma homebroker (Estudio Gallo). Se usa para recibir precios y datos de mercado en tiempo real. Permite tambien obtener data historica.
#
#
# Mas info e instrucciones de instalacion en https://pypi.org/project/pyhomebroker/
#
# Estudio Gallo: http://www.estudiogallo.com.ar/
#
# Home Broker: https://www.youtube.com/watch?v=ippFga_hKSg
#
# Creador : https://twitter.com/diegodegese

# %% [markdown]
# ### por obvias razones, no revelo mis datos personales :) Pero aqui habria que crear un diccionario con sus datos
#
# Previamente lo guarde en un archivo pickle y ahora lo recupero

# %%
#TO SAVE
#personal_data = {'ByMA_id' : BymaId,
#                 'dni'     : dni, 
#                 'user'    : user,
#                 'password': password}
#pickle.dump(personal_data, open("personal_data.info", "wb"))

#TO LOAD
import pickle
personal_data = pickle.load(open("personal_data.info", "rb"))

# %%
personal_data['ByMA_id']
# Out:
# 209

# %% [markdown]
# ### Metodos disponibles

# %%
panel_opciones_homebroker_all_raw = panel_opciones_homebroker(personal_data,
                                                              ticker = '', 
                                                              clean_flag=False)
panel_opciones_homebroker_all_raw
# Out:
#          symbol  last  change  open  high  low  previous_close  turnover  \
# 0    AGRC17.0AG   NaN     NaN   NaN   NaN  NaN             NaN       NaN
# 1    AGRC24.0AG   NaN     NaN   NaN   NaN  NaN           5.800       NaN
# 2    AGRC24.0OC   NaN     NaN   NaN   NaN  NaN             NaN       NaN
# 3    ALUC31.0AG   NaN     NaN   NaN   NaN  NaN          28.000       NaN
# 4    ALUC31.0OC   NaN     NaN   NaN   NaN  NaN          30.002       NaN
# ..          ...   ...     ...   ...   ...  ...             ...       ...
# 282  YPFV760.AG   NaN     NaN   NaN   NaN  NaN          30.000       NaN
# 283  YPFV760.DI   NaN     NaN   NaN   NaN  NaN          50.000       NaN
# 284  YPFV800.AG   NaN     NaN   NaN   NaN  NaN          52.000       NaN
# 285  YPFV800.OC   NaN     NaN   NaN   NaN  NaN          54.000       NaN
# 286  YPFV880.AG   NaN     NaN   NaN   NaN  NaN          55.000       NaN
#
#      volume  operations datetime expiration  strike  kind underlying_asset
# 0       NaN         NaN      NaT 2021-08-20    17.0  CALL             AGRO
# 1       NaN         NaN      NaT 2021-08-20    24.0  CALL             AGRO
# 2       NaN         NaN      NaT 2021-10-15    24.0  CALL             AGRO
# 3       NaN         NaN      NaT 2021-08-20    31.0  CALL             ALUA
# 4       NaN         NaN      NaT 2021-10-15    31.0  CALL             ALUA
# ..      ...         ...      ...        ...     ...   ...              ...
# 282     NaN         NaN      NaT 2021-08-20   760.0   PUT             YPFD
# 283     NaN         NaN      NaT 2021-12-17   760.0   PUT             YPFD
# 284     NaN         NaN      NaT 2021-08-20   800.0   PUT             YPFD
# 285     NaN         NaN      NaT 2021-10-15   800.0   PUT             YPFD
# 286     NaN         NaN      NaT 2021-08-20   880.0   PUT             YPFD
#
# [287 rows x 15 columns]

# %%
panel_opciones_homebroker_all_clean = panel_opciones_homebroker(personal_data, 
                                                                ticker = '', 
                                                                clean_flag=True)
panel_opciones_homebroker_all_clean
# Out:
#        Especie Ticker    Spot CallPut  Strike  TTM    Last   Close  Moneyness
# 0   ALUC31.0AG   ALUA   57.20       C   31.00   43  30.999  28.000   1.845161
# 1   CEPC34.0AG   CEPU   41.45       C   34.00   43  11.000   9.020   1.219118
# 2   GFGV87.0AG   GGAL  143.00       P   87.00   43   0.105   0.130   1.643678
# 3   GFGV90.0AG   GGAL  143.00       P   90.00   43   0.210   0.150   1.588889
# 4   GFGV13098G   GGAL  143.00       P  130.98   43   2.800   2.307   1.091770
# 5   GFGC13898G   GGAL  143.00       C  138.98   43  15.000  16.570   1.028925
# 6   GFGV13898G   GGAL  143.00       P  138.98   43   5.100   4.417   1.028925
# 7   GFGC145.AG   GGAL  143.00       C  145.00   43  11.500  13.094   0.986207
# 8   GFGV145.AG   GGAL  143.00       P  145.00   43   8.000   6.700   0.986207
# 9   GFGC14898G   GGAL  143.00       C  148.98   43  10.000  11.422   0.959860
# 10  GFGV14898G   GGAL  143.00       P  148.98   43   9.950   8.460   0.959860
# 11  GFGC15898G   GGAL  143.00       C  158.98   43   6.500   7.643   0.899484
# 12  GFGC16898G   GGAL  143.00       C  168.98   43   4.300   5.100   0.846254
# 13  GFGV16898G   GGAL  143.00       P  168.98   43  25.000  23.067   0.846254
# 14  GFGC180.AG   GGAL  143.00       C  180.00   43   2.795   3.101   0.794444
# 15  GFGC185.AG   GGAL  143.00       C  185.00   43   2.500   2.550   0.772973
# 16  GFGC190.AG   GGAL  143.00       C  190.00   43   2.000   2.151   0.752632
# 17  GFGC19898G   GGAL  143.00       C  198.98   43   1.499   1.655   0.718665
# 18  GFGC220.AG   GGAL  143.00       C  220.00   43   1.129   1.209   0.650000
# 19  GFGC230.AG   GGAL  143.00       C  230.00   43   0.847   1.097   0.621739
# 20  GFGC240.AG   GGAL  143.00       C  240.00   43   0.965   0.994   0.595833
# 21  TGNC60.0AG  TGNO4   55.50       C   60.00   43   5.950   4.900   0.925000
# 22  TRAC22.0AG   TRAN   30.20       C   22.00   43  10.110  11.600   1.372727
# 23  YPFV500.AG   YPFD  752.55       P  500.00   43   0.150   0.150   1.505100
# 24  YPFV580.AG   YPFD  752.55       P  580.00   43   1.400   0.601   1.297500
# 25  GFGC117.OC   GGAL  143.00       C  117.00   99  40.000  40.500   1.222222
# 26  GFGC160.OC   GGAL  143.00       C  160.00   99  13.000  15.000   0.893750

# %%
panel_opciones_homebroker_GGAL_clean = panel_opciones_homebroker(personal_data, 'GGAL', True)
panel_opciones_homebroker_GGAL_clean
# Out:
#        Especie Ticker   Spot CallPut  Strike  TTM    Last   Close  Moneyness
# 0   GFGV87.0AG   GGAL  143.0       P   87.00   43   0.105   0.130   1.643678
# 1   GFGV90.0AG   GGAL  143.0       P   90.00   43   0.209   0.150   1.588889
# 2   GFGV13098G   GGAL  143.0       P  130.98   43   2.800   2.307   1.091770
# 3   GFGC13898G   GGAL  143.0       C  138.98   43  15.000  16.570   1.028925
# 4   GFGV13898G   GGAL  143.0       P  138.98   43   5.100   4.417   1.028925
# 5   GFGC145.AG   GGAL  143.0       C  145.00   43  11.500  13.094   0.986207
# 6   GFGV145.AG   GGAL  143.0       P  145.00   43   8.000   6.700   0.986207
# 7   GFGC14898G   GGAL  143.0       C  148.98   43  10.000  11.422   0.959860
# 8   GFGV14898G   GGAL  143.0       P  148.98   43   9.950   8.460   0.959860
# 9   GFGC15898G   GGAL  143.0       C  158.98   43   6.500   7.643   0.899484
# 10  GFGC16898G   GGAL  143.0       C  168.98   43   4.300   5.100   0.846254
# 11  GFGV16898G   GGAL  143.0       P  168.98   43  25.100  23.067   0.846254
# 12  GFGC180.AG   GGAL  143.0       C  180.00   43   2.795   3.101   0.794444
# 13  GFGC185.AG   GGAL  143.0       C  185.00   43   2.500   2.550   0.772973
# 14  GFGC190.AG   GGAL  143.0       C  190.00   43   2.000   2.151   0.752632
# 15  GFGC19898G   GGAL  143.0       C  198.98   43   1.499   1.655   0.718665
# 16  GFGC220.AG   GGAL  143.0       C  220.00   43   1.129   1.209   0.650000
# 17  GFGC230.AG   GGAL  143.0       C  230.00   43   0.847   1.097   0.621739
# 18  GFGC240.AG   GGAL  143.0       C  240.00   43   0.965   0.994   0.595833
# 19  GFGC117.OC   GGAL  143.0       C  117.00   99  40.000  40.500   1.222222
# 20  GFGC160.OC   GGAL  143.0       C  160.00   99  13.000  15.000   0.893750

# %% [markdown]
# ### Que hace el metodo adentro

# %% [markdown]
# #### a) Recupero la informacion del picke (esto es personal!)

# %%
# Recupero la informacion del pickle

ByMA_id = personal_data['ByMA_id']
dni = personal_data['dni']
user = personal_data['user']
password = personal_data['password']

# %% [markdown]
# #### b) Conecto con el cliente

# %%
hb = HomeBroker(ByMA_id)
hb.auth.login(dni, user, password, raise_exception=True)
# Connect to the server
hb.online.connect()

# %% [markdown]
# #### c) Obtengo una 'foto'-snapshot del mercado

# %%
snapshot = hb.online.get_market_snapshot()

# %%
snapshot
# Out:
# {'bluechips':                      last  change   open   high     low  previous_close  \
#  symbol settlement
#  ALUA   spot         57.00   -1.21   57.0   57.0   57.00           57.70
#         24hs           NaN     NaN    NaN    NaN     NaN           59.40
#         48hs         57.20   -2.55   58.5   58.5   57.20           58.70
#  BBAR   spot           NaN     NaN    NaN    NaN     NaN          180.50
#         24hs           NaN     NaN    NaN    NaN     NaN          192.00
#  ...                   ...     ...    ...    ...     ...             ...
#  VALO   24hs           NaN     NaN    NaN    NaN     NaN           28.75
#         48hs         26.00   -1.14   26.1   26.1   26.00           26.30
#  YPFD   spot        750.00   -2.00  750.0  750.0  750.00          765.35
#         24hs           NaN     NaN    NaN    NaN     NaN          763.00
#         48hs        750.25   -2.29  758.4  758.4  750.25          767.90
#
#                     turnover  volume  operations            datetime
#  symbol settlement
#  ALUA   spot           228.0     4.0         1.0 2021-07-08 11:00:23
#         24hs             NaN     NaN         NaN                 NaT
#         48hs         77967.0  1351.0        20.0 2021-07-08 11:02:37
#  BBAR   spot             NaN     NaN         NaN                 NaT
#         24hs             NaN     NaN         NaN                 NaT
#  ...                     ...     ...         ...                 ...
#  VALO   24hs             NaN     NaN         NaN                 NaT
#         48hs         20120.0   772.0         8.0 2021-07-08 11:02:20
#  YPFD   spot          2250.0     3.0         1.0 2021-07-08 11:00:42
#         24hs             NaN     NaN         NaN                 NaT
#         48hs        693156.0   921.0        32.0 2021-07-08 11:03:11
#
#  [66 rows x 10 columns],
#  'general_board':                     last  change   open   high    low  previous_close  \
#  symbol settlement
#  AGRO   spot        28.00    4.47  28.00  28.00  28.00           26.80
#         24hs          NaN     NaN    NaN    NaN    NaN           26.75
#         48hs        26.90     NaN  26.80  26.90  26.45           26.90
#  AUSO   spot          NaN     NaN    NaN    NaN    NaN           98.00
#         24hs          NaN     NaN    NaN    NaN    NaN           82.20
#  ...                  ...     ...    ...    ...    ...             ...
#  SEMI   24hs          NaN     NaN    NaN    NaN    NaN            5.53
#         48hs         5.75    0.87   5.75   5.75   5.75            5.70
#  TGLT   spot          NaN     NaN    NaN    NaN    NaN            4.10
#         24hs          NaN     NaN    NaN    NaN    NaN            3.80
#         48hs         4.18    3.20   4.05   4.18   4.05            4.05
#
#                     turnover   volume  operations            datetime
#  symbol settlement
#  AGRO   spot           280.0     10.0         1.0 2021-07-08 11:00:06
#         24hs             NaN      NaN         NaN                 NaT
#         48hs         52958.0   1977.0        17.0 2021-07-08 11:02:40
#  AUSO   spot             NaN      NaN         NaN                 NaT
#         24hs             NaN      NaN         NaN                 NaT
#  ...                     ...      ...         ...                 ...
#  SEMI   24hs             NaN      NaN         NaN                 NaT
#         48hs           575.0    100.0         2.0 2021-07-08 11:00:24
#  TGLT   spot             NaN      NaN         NaN                 NaT
#         24hs             NaN      NaN         NaN                 NaT
#         48hs         54990.0  13248.0         7.0 2021-07-08 11:00:33
#
#  [151 rows x 10 columns],
#  'cedears':                      last  change    open    high     low  previous_close  \
#  symbol settlement
#  AAPL   spot        2470.0   -1.20  2500.0  2513.0  2469.0         2500.00
#         24hs           NaN     NaN     NaN     NaN     NaN         2500.00
#         48hs        2452.0   -2.36  2468.0  2468.0  2446.5         2511.50
#  AAPLB  spot           NaN     NaN     NaN     NaN     NaN         2170.00
#         24hs           NaN     NaN     NaN     NaN     NaN         1830.00
#  ...                   ...     ...     ...     ...     ...             ...
#  ZM     24hs           NaN     NaN     NaN     NaN     NaN         1067.50
#         48hs        1440.0   -1.36  1438.5  1440.0  1438.5         1460.00
#  ZMD    spot           NaN     NaN     NaN     NaN     NaN            8.25
#         24hs           NaN     NaN     NaN     NaN     NaN             NaN
#         48hs           NaN     NaN     NaN     NaN     NaN            8.60
#
#                      turnover  volume  operations            datetime
#  symbol settlement
#  AAPL   spot          82202.0    33.0         7.0 2021-07-08 11:03:05
#         24hs              NaN     NaN         NaN                 NaT
#         48hs        4406805.0  1796.0       136.0 2021-07-08 11:03:18
#  AAPLB  spot              NaN     NaN         NaN                 NaT
#         24hs              NaN     NaN         NaN                 NaT
#  ...                      ...     ...         ...                 ...
#  ZM     24hs              NaN     NaN         NaN                 NaT
#         48hs          25898.0    18.0         5.0 2021-07-08 11:02:09
#  ZMD    spot              NaN     NaN         NaN                 NaT
#         24hs              NaN     NaN         NaN                 NaT
#         48hs              NaN     NaN         NaN                 NaT
#
#  [875 rows x 10 columns],
#  'government_bonds':                    last  change  open  high  low  previous_close  turnover  \
#  symbol settlement
#  AA22   spot         NaN     NaN   NaN   NaN  NaN          98.700       NaN
#         24hs         NaN     NaN   NaN   NaN  NaN          93.799       NaN
#         48hs         NaN     NaN   NaN   NaN  NaN          98.700       NaN
#  AA25   spot         NaN     NaN   NaN   NaN  NaN        5200.000       NaN
#         24hs         NaN     NaN   NaN   NaN  NaN        6200.000       NaN
#  ...                 ...     ...   ...   ...  ...             ...       ...
#  TX28   24hs         NaN     NaN   NaN   NaN  NaN          99.596       NaN
#         48hs         NaN     NaN   NaN   NaN  NaN         111.000       NaN
#  TY22P  spot         NaN     NaN   NaN   NaN  NaN             NaN       NaN
#         24hs         NaN     NaN   NaN   NaN  NaN             NaN       NaN
#         48hs         NaN     NaN   NaN   NaN  NaN          80.000       NaN
#
#                     volume  operations datetime
#  symbol settlement
#  AA22   spot           NaN         NaN      NaT
#         24hs           NaN         NaN      NaT
#         48hs           NaN         NaN      NaT
#  AA25   spot           NaN         NaN      NaT
#         24hs           NaN         NaN      NaT
#  ...                   ...         ...      ...
#  TX28   24hs           NaN         NaN      NaT
#         48hs           NaN         NaN      NaT
#  TY22P  spot           NaN         NaN      NaT
#         24hs           NaN         NaN      NaT
#         48hs           NaN         NaN      NaT
#
#  [387 rows x 10 columns],
#  'short_term_government_bonds':                    last  change  open  high  low  previous_close  turnover  \
#  symbol settlement
#  S29O1  spot         NaN     NaN   NaN   NaN  NaN          89.250       NaN
#         24hs         NaN     NaN   NaN   NaN  NaN          88.600       NaN
#         48hs         NaN     NaN   NaN   NaN  NaN          89.700       NaN
#  S2LC   spot         NaN     NaN   NaN   NaN  NaN           0.663       NaN
#         24hs         NaN     NaN   NaN   NaN  NaN             NaN       NaN
#  ...                 ...     ...   ...   ...  ...             ...       ...
#  XJ2D   24hs         NaN     NaN   NaN   NaN  NaN             NaN       NaN
#         48hs         NaN     NaN   NaN   NaN  NaN             NaN       NaN
#  XS1D   spot         NaN     NaN   NaN   NaN  NaN             NaN       NaN
#         24hs         NaN     NaN   NaN   NaN  NaN             NaN       NaN
#         48hs         NaN     NaN   NaN   NaN  NaN             NaN       NaN
#
#                     volume  operations datetime
#  symbol settlement
#  S29O1  spot           NaN         NaN      NaT
#         24hs           NaN         NaN      NaT
#         48hs           NaN         NaN      NaT
#  S2LC   spot           NaN         NaN      NaT
#         24hs           NaN         NaN      NaT
#  ...                   ...         ...      ...
#  XJ2D   24hs           NaN         NaN      NaT
#         48hs           NaN         NaN      NaT
#  XS1D   spot           NaN         NaN      NaT
#         24hs           NaN         NaN      NaT
#         48hs           NaN         NaN      NaT
#
#  [117 rows x 10 columns],
#  'corporate_bonds':                    last  change  open  high  low  previous_close  turnover  \
#  symbol settlement
#  AER2C  spot         NaN     NaN   NaN   NaN  NaN           52.00       NaN
#         24hs         NaN     NaN   NaN   NaN  NaN           51.70       NaN
#         48hs         NaN     NaN   NaN   NaN  NaN           51.48       NaN
#  AER2D  spot         NaN     NaN   NaN   NaN  NaN           53.00       NaN
#         24hs         NaN     NaN   NaN   NaN  NaN           54.00       NaN
#  ...                 ...     ...   ...   ...  ...             ...       ...
#  YPCUD  24hs         NaN     NaN   NaN   NaN  NaN           93.00       NaN
#         48hs         NaN     NaN   NaN   NaN  NaN           96.50       NaN
#  YPCUO  spot         NaN     NaN   NaN   NaN  NaN        15800.00       NaN
#         24hs         NaN     NaN   NaN   NaN  NaN        15500.00       NaN
#         48hs         NaN     NaN   NaN   NaN  NaN        16200.00       NaN
#
#                     volume  operations datetime
#  symbol settlement
#  AER2C  spot           NaN         NaN      NaT
#         24hs           NaN         NaN      NaT
#         48hs           NaN         NaN      NaT
#  AER2D  spot           NaN         NaN      NaT
#         24hs           NaN         NaN      NaT
#  ...                   ...         ...      ...
#  YPCUD  24hs           NaN         NaN      NaT
#         48hs           NaN         NaN      NaT
#  YPCUO  spot           NaN         NaN      NaT
#         24hs           NaN         NaN      NaT
#         48hs           NaN         NaN      NaT
#
#  [398 rows x 10 columns],
#  'options':               last  change    open    high     low  previous_close  turnover  \
#  symbol
#  AGRC17.0AG     NaN     NaN     NaN     NaN     NaN             NaN       NaN
#  AGRC24.0AG     NaN     NaN     NaN     NaN     NaN           5.800       NaN
#  AGRC24.0OC     NaN     NaN     NaN     NaN     NaN             NaN       NaN
#  ALUC31.0AG  30.999   10.71  30.999  30.999  30.999          28.000  185994.0
#  ALUC31.0OC     NaN     NaN     NaN     NaN     NaN          30.002       NaN
#  ...            ...     ...     ...     ...     ...             ...       ...
#  YPFV760.AG     NaN     NaN     NaN     NaN     NaN          30.000       NaN
#  YPFV760.DI     NaN     NaN     NaN     NaN     NaN          50.000       NaN
#  YPFV800.AG     NaN     NaN     NaN     NaN     NaN          52.000       NaN
#  YPFV800.OC     NaN     NaN     NaN     NaN     NaN          54.000       NaN
#  YPFV880.AG     NaN     NaN     NaN     NaN     NaN          55.000       NaN
#
#              volume  operations            datetime expiration  strike  kind  \
#  symbol
#  AGRC17.0AG     NaN         NaN                 NaT 2021-08-20    17.0  CALL
#  AGRC24.0AG     NaN         NaN                 NaT 2021-08-20    24.0  CALL
#  AGRC24.0OC     NaN         NaN                 NaT 2021-10-15    24.0  CALL
#  ALUC31.0AG    60.0         1.0 2021-07-08 11:02:44 2021-08-20    31.0  CALL
#  ALUC31.0OC     NaN         NaN                 NaT 2021-10-15    31.0  CALL
#  ...            ...         ...                 ...        ...     ...   ...
#  YPFV760.AG     NaN         NaN                 NaT 2021-08-20   760.0   PUT
#  YPFV760.DI     NaN         NaN                 NaT 2021-12-17   760.0   PUT
#  YPFV800.AG     NaN         NaN                 NaT 2021-08-20   800.0   PUT
#  YPFV800.OC     NaN         NaN                 NaT 2021-10-15   800.0   PUT
#  YPFV880.AG     NaN         NaN                 NaT 2021-08-20   880.0   PUT
#
#             underlying_asset
#  symbol
#  AGRC17.0AG             AGRO
#  AGRC24.0AG             AGRO
#  AGRC24.0OC             AGRO
#  ALUC31.0AG             ALUA
#  ALUC31.0OC             ALUA
#  ...                     ...
#  YPFV760.AG             YPFD
#  YPFV760.DI             YPFD
#  YPFV800.AG             YPFD
#  YPFV800.OC             YPFD
#  YPFV880.AG             YPFD
#
#  [287 rows x 14 columns]}

# %%
panel_opciones = snapshot['options']
panel_merval = snapshot['bluechips']
panel_general = snapshot['general_board']
panel_cedears = snapshot['cedears']

# %%
#Asi se ve lo que obtengo de la API
panel_opciones
# Out:
#               last  change    open    high     low  previous_close  turnover  \
# symbol
# AGRC17.0AG     NaN     NaN     NaN     NaN     NaN             NaN       NaN
# AGRC24.0AG     NaN     NaN     NaN     NaN     NaN           5.800       NaN
# AGRC24.0OC     NaN     NaN     NaN     NaN     NaN             NaN       NaN
# ALUC31.0AG  30.999   10.71  30.999  30.999  30.999          28.000  185994.0
# ALUC31.0OC     NaN     NaN     NaN     NaN     NaN          30.002       NaN
# ...            ...     ...     ...     ...     ...             ...       ...
# YPFV760.AG     NaN     NaN     NaN     NaN     NaN          30.000       NaN
# YPFV760.DI     NaN     NaN     NaN     NaN     NaN          50.000       NaN
# YPFV800.AG     NaN     NaN     NaN     NaN     NaN          52.000       NaN
# YPFV800.OC     NaN     NaN     NaN     NaN     NaN          54.000       NaN
# YPFV880.AG     NaN     NaN     NaN     NaN     NaN          55.000       NaN
#
#             volume  operations            datetime expiration  strike  kind  \
# symbol
# AGRC17.0AG     NaN         NaN                 NaT 2021-08-20    17.0  CALL
# AGRC24.0AG     NaN         NaN                 NaT 2021-08-20    24.0  CALL
# AGRC24.0OC     NaN         NaN                 NaT 2021-10-15    24.0  CALL
# ALUC31.0AG    60.0         1.0 2021-07-08 11:02:44 2021-08-20    31.0  CALL
# ALUC31.0OC     NaN         NaN                 NaT 2021-10-15    31.0  CALL
# ...            ...         ...                 ...        ...     ...   ...
# YPFV760.AG     NaN         NaN                 NaT 2021-08-20   760.0   PUT
# YPFV760.DI     NaN         NaN                 NaT 2021-12-17   760.0   PUT
# YPFV800.AG     NaN         NaN                 NaT 2021-08-20   800.0   PUT
# YPFV800.OC     NaN         NaN                 NaT 2021-10-15   800.0   PUT
# YPFV880.AG     NaN         NaN                 NaT 2021-08-20   880.0   PUT
#
#            underlying_asset
# symbol
# AGRC17.0AG             AGRO
# AGRC24.0AG             AGRO
# AGRC24.0OC             AGRO
# ALUC31.0AG             ALUA
# ALUC31.0OC             ALUA
# ...                     ...
# YPFV760.AG             YPFD
# YPFV760.DI             YPFD
# YPFV800.AG             YPFD
# YPFV800.OC             YPFD
# YPFV880.AG             YPFD
#
# [287 rows x 14 columns]

# %% [markdown]
# #### d) Limpiando el dataset

# %%
# Le agrego columnas nuevas
panel_opciones['Spot'] = 0.0 
panel_opciones['TTM']=0
panel_opciones['Moneyness']=0.0

# %%
#Genero la columna TTM
hoy = datetime.datetime.today()
      
#Codigo para obtener el TTM
x= (panel_opciones['expiration'] - hoy).values        
days = x.astype('timedelta64[D]')
ttm_f = (days+1) / np.timedelta64(1, 'D')
       
panel_opciones['TTM'] = ttm_f.astype(np.int64)

# %%
#panel_opciones = panel_opciones.reset_index()
panel_opciones
# Out:
#               last  change    open    high     low  previous_close  turnover  \
# symbol
# AGRC17.0AG     NaN     NaN     NaN     NaN     NaN             NaN       NaN
# AGRC24.0AG     NaN     NaN     NaN     NaN     NaN           5.800       NaN
# AGRC24.0OC     NaN     NaN     NaN     NaN     NaN             NaN       NaN
# ALUC31.0AG  30.999   10.71  30.999  30.999  30.999          28.000  185994.0
# ALUC31.0OC     NaN     NaN     NaN     NaN     NaN          30.002       NaN
# ...            ...     ...     ...     ...     ...             ...       ...
# YPFV760.AG     NaN     NaN     NaN     NaN     NaN          30.000       NaN
# YPFV760.DI     NaN     NaN     NaN     NaN     NaN          50.000       NaN
# YPFV800.AG     NaN     NaN     NaN     NaN     NaN          52.000       NaN
# YPFV800.OC     NaN     NaN     NaN     NaN     NaN          54.000       NaN
# YPFV880.AG     NaN     NaN     NaN     NaN     NaN          55.000       NaN
#
#             volume  operations            datetime expiration  strike  kind  \
# symbol
# AGRC17.0AG     NaN         NaN                 NaT 2021-08-20    17.0  CALL
# AGRC24.0AG     NaN         NaN                 NaT 2021-08-20    24.0  CALL
# AGRC24.0OC     NaN         NaN                 NaT 2021-10-15    24.0  CALL
# ALUC31.0AG    60.0         1.0 2021-07-08 11:02:44 2021-08-20    31.0  CALL
# ALUC31.0OC     NaN         NaN                 NaT 2021-10-15    31.0  CALL
# ...            ...         ...                 ...        ...     ...   ...
# YPFV760.AG     NaN         NaN                 NaT 2021-08-20   760.0   PUT
# YPFV760.DI     NaN         NaN                 NaT 2021-12-17   760.0   PUT
# YPFV800.AG     NaN         NaN                 NaT 2021-08-20   800.0   PUT
# YPFV800.OC     NaN         NaN                 NaT 2021-10-15   800.0   PUT
# YPFV880.AG     NaN         NaN                 NaT 2021-08-20   880.0   PUT
#
#            underlying_asset  Spot  TTM  Moneyness
# symbol
# AGRC17.0AG             AGRO   0.0   43        0.0
# AGRC24.0AG             AGRO   0.0   43        0.0
# AGRC24.0OC             AGRO   0.0   99        0.0
# ALUC31.0AG             ALUA   0.0   43        0.0
# ALUC31.0OC             ALUA   0.0   99        0.0
# ...                     ...   ...  ...        ...
# YPFV760.AG             YPFD   0.0   43        0.0
# YPFV760.DI             YPFD   0.0  162        0.0
# YPFV800.AG             YPFD   0.0   43        0.0
# YPFV800.OC             YPFD   0.0   99        0.0
# YPFV880.AG             YPFD   0.0   43        0.0
#
# [287 rows x 17 columns]

# %%
# Renombro las columnas, renombro el tipo Call/Put, reordeno y me quedo solo con las columnas que quiero
panel_opciones = panel_opciones.reset_index()
panel_opciones = panel_opciones.rename(
            columns={'symbol':'Especie','underlying_asset':'Ticker', 'kind': 'CallPut', 'last': 'Last', 'strike': 'Strike','previous_close':'Close'}, inplace=False)
       
panel_opciones['CallPut'] = pd.Series(panel_opciones['CallPut']).str.replace('CALL', 'C', regex=True)
panel_opciones['CallPut'] = pd.Series(panel_opciones['CallPut']).str.replace('PUT', 'P', regex=True)
       
panel_opciones = panel_opciones.sort_values(['TTM', 'Ticker', 'Strike', 'CallPut'])
panel_opciones = panel_opciones[
            ['Especie','Ticker', 'Spot', 'CallPut', 'Strike', 'TTM', 'Last', 'Close','Moneyness']]

# %%
# Agrego el spot y el moneyness
# get_spot_from_ticker es un metodo propio

for fila in range(len(panel_opciones.Especie.values)):
    ticker_ = panel_opciones.Ticker.values[fila]
    panel_opciones['Spot'].values[fila] = get_spot_from_ticker(ticker_,snapshot)
        
panel_opciones['Moneyness']= panel_opciones['Spot'] / panel_opciones['Strike']

panel_opciones
# Out:
#         Especie Ticker     Spot CallPut   Strike  TTM  Last   Close  Moneyness
# 0    GFGC180.JL   GGAL   143.00       C   180.00    8   NaN    3.50   0.794444
# 1    APLC16979G   AAPL  2452.00       C  1697.90   43   NaN  850.00   1.444137
# 2    APLC2000AG   AAPL  2452.00       C  2000.00   43   NaN  406.00   1.226000
# 3    APLC2100AG   AAPL  2452.00       C  2100.00   43   NaN  500.00   1.167619
# 4    APLV2200AG   AAPL  2452.00       P  2200.00   43   NaN   35.00   1.114545
# ..          ...    ...      ...     ...      ...  ...   ...     ...        ...
# 282  COMC1.19DI   COME     4.78       C     1.19  162   NaN    4.30   4.016807
# 283  GFGC170.DI   GGAL   143.00       C   170.00  162   NaN   18.50   0.841176
# 284  GFGC240.DI   GGAL   143.00       C   240.00  162   NaN    4.25   0.595833
# 285  YPFC760.DI   YPFD   750.25       C   760.00  162   NaN     NaN   0.987171
# 286  YPFV760.DI   YPFD   750.25       P   760.00  162   NaN   50.00   0.987171
#
# [287 rows x 9 columns]

# %%
#Limpieza final
#Saco las Nan
panel_opciones = panel_opciones[pd.notna(panel_opciones.Last)]
# saco la columna indice vieja
panel_opciones = panel_opciones.reset_index()
del panel_opciones['index']

# %%
panel_opciones
# Out:
#        Especie Ticker    Spot CallPut  Strike  TTM    Last   Close  Moneyness
# 0   ALUC31.0AG   ALUA   57.20       C   31.00   43  30.999  28.000   1.845161
# 1   CEPC34.0AG   CEPU   41.45       C   34.00   43  11.000   9.020   1.219118
# 2   GFGV87.0AG   GGAL  143.00       P   87.00   43   0.105   0.130   1.643678
# 3   GFGV90.0AG   GGAL  143.00       P   90.00   43   0.209   0.150   1.588889
# 4   GFGV13098G   GGAL  143.00       P  130.98   43   2.800   2.307   1.091770
# 5   GFGC13898G   GGAL  143.00       C  138.98   43  15.000  16.570   1.028925
# 6   GFGV13898G   GGAL  143.00       P  138.98   43   5.370   4.417   1.028925
# 7   GFGC145.AG   GGAL  143.00       C  145.00   43  11.500  13.094   0.986207
# 8   GFGV145.AG   GGAL  143.00       P  145.00   43   8.000   6.700   0.986207
# 9   GFGC14898G   GGAL  143.00       C  148.98   43  10.000  11.422   0.959860
# 10  GFGV14898G   GGAL  143.00       P  148.98   43   9.900   8.460   0.959860
# 11  GFGC15898G   GGAL  143.00       C  158.98   43   6.500   7.643   0.899484
# 12  GFGC16898G   GGAL  143.00       C  168.98   43   4.300   5.100   0.846254
# 13  GFGV16898G   GGAL  143.00       P  168.98   43  25.000  23.067   0.846254
# 14  GFGC180.AG   GGAL  143.00       C  180.00   43   2.795   3.101   0.794444
# 15  GFGC185.AG   GGAL  143.00       C  185.00   43   2.500   2.550   0.772973
# 16  GFGC190.AG   GGAL  143.00       C  190.00   43   2.000   2.151   0.752632
# 17  GFGC19898G   GGAL  143.00       C  198.98   43   1.499   1.655   0.718665
# 18  GFGC220.AG   GGAL  143.00       C  220.00   43   1.129   1.209   0.650000
# 19  GFGC230.AG   GGAL  143.00       C  230.00   43   0.847   1.097   0.621739
# 20  GFGC240.AG   GGAL  143.00       C  240.00   43   0.965   0.994   0.595833
# 21  TGNC60.0AG  TGNO4   55.50       C   60.00   43   5.950   4.900   0.925000
# 22  TRAC22.0AG   TRAN   30.20       C   22.00   43  10.110  11.600   1.372727
# 23  YPFV500.AG   YPFD  750.25       P  500.00   43   0.150   0.150   1.500500
# 24  YPFV580.AG   YPFD  750.25       P  580.00   43   1.400   0.601   1.293534
# 25  GFGC117.OC   GGAL  143.00       C  117.00   99  40.000  40.500   1.222222
# 26  GFGC160.OC   GGAL  143.00       C  160.00   99  13.000  15.000   0.893750

# %%
# SI solamente quiero un ticker

panel_opciones_ggal = panel_opciones[panel_opciones.Ticker == 'GGAL']

panel_opciones_ggal = panel_opciones_ggal.reset_index()
del panel_opciones_ggal['index']
panel_opciones_ggal
# Out:
#        Especie Ticker   Spot CallPut  Strike  TTM    Last   Close  Moneyness
# 0   GFGV87.0AG   GGAL  143.0       P   87.00   43   0.105   0.130   1.643678
# 1   GFGV90.0AG   GGAL  143.0       P   90.00   43   0.209   0.150   1.588889
# 2   GFGV13098G   GGAL  143.0       P  130.98   43   2.800   2.307   1.091770
# 3   GFGC13898G   GGAL  143.0       C  138.98   43  15.000  16.570   1.028925
# 4   GFGV13898G   GGAL  143.0       P  138.98   43   5.370   4.417   1.028925
# 5   GFGC145.AG   GGAL  143.0       C  145.00   43  11.500  13.094   0.986207
# 6   GFGV145.AG   GGAL  143.0       P  145.00   43   8.000   6.700   0.986207
# 7   GFGC14898G   GGAL  143.0       C  148.98   43  10.000  11.422   0.959860
# 8   GFGV14898G   GGAL  143.0       P  148.98   43   9.900   8.460   0.959860
# 9   GFGC15898G   GGAL  143.0       C  158.98   43   6.500   7.643   0.899484
# 10  GFGC16898G   GGAL  143.0       C  168.98   43   4.300   5.100   0.846254
# 11  GFGV16898G   GGAL  143.0       P  168.98   43  25.000  23.067   0.846254
# 12  GFGC180.AG   GGAL  143.0       C  180.00   43   2.795   3.101   0.794444
# 13  GFGC185.AG   GGAL  143.0       C  185.00   43   2.500   2.550   0.772973
# 14  GFGC190.AG   GGAL  143.0       C  190.00   43   2.000   2.151   0.752632
# 15  GFGC19898G   GGAL  143.0       C  198.98   43   1.499   1.655   0.718665
# 16  GFGC220.AG   GGAL  143.0       C  220.00   43   1.129   1.209   0.650000
# 17  GFGC230.AG   GGAL  143.0       C  230.00   43   0.847   1.097   0.621739
# 18  GFGC240.AG   GGAL  143.0       C  240.00   43   0.965   0.994   0.595833
# 19  GFGC117.OC   GGAL  143.0       C  117.00   99  40.000  40.500   1.222222
# 20  GFGC160.OC   GGAL  143.0       C  160.00   99  13.000  15.000   0.893750

# %%
personal_data = {'ByMA_id' : 'BymaId',
                 'dni'     : 'dni', 
                 'user'    : 'user',
                 'password': 'password'}

personal_data
# Out:
# {'ByMA_id': 'BymaId', 'dni': 'dni', 'user': 'user', 'password': 'password'}
