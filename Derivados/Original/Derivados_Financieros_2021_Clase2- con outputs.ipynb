# %% [markdown]
# # Derivados Financieros 2021 - Clase 2

# %% [markdown]
# ## 1) Modulo yfinance para Yahoo Finance
# ## 2) Plots
# ## 3) Payoffs - Estraegias

# %%
### Importo los modulos

from data_nyse import *

import yfinance as yf
import datetime

# %% [markdown]
# ## API Yahoo finance

# %% [markdown]
# Modulos necesarios
#
# data_nyse (en webcampus) ;
#
# pandas,
#
# matplotlib,
#
# datetime,
#
# yfinance, (yfinance-0.1.63 - tuve que actualizar reicentemente)
#
# sys,
#
# Instalarlos con Anaconda, comando Conda o comando pip install
#
#
# urllib.requestatexit
# datetime
# dateutil
#
# import tda
# json
# selenium, webdriver

# %% [markdown]
# ## Queremos emular lo que hicimos para BYMA

# %%
### Metodo para el web scraping
panel_yahoo_GGAL = obtener_opciones_yahoo_finance('GGAL')
panel_yahoo_GGAL
# Out:
#         contractSymbol       lastTradeDate  strike  lastPrice    bid    ask  \
# 0  GGAL210820C00005000 2021-06-25 15:09:02     5.0       4.30   2.50   3.10
# 1  GGAL210820C00007500 2021-07-29 17:55:17     7.5       0.90   0.65   0.85
# 2  GGAL210820C00010000 2021-07-27 19:42:51    10.0       0.05   0.00   0.05
# 3  GGAL210820C00012500 2021-06-23 17:18:27    12.5       0.10   0.00   0.55
# 0  GGAL210917C00007500 2021-07-28 18:40:40     7.5       1.10   0.85   1.20
# 1  GGAL210917C00010000 2021-07-21 19:09:36    10.0       0.20   0.00   0.20
# 0  GGAL211015C00005000 2021-06-08 14:49:02     5.0       5.10   3.10   3.30
# 1  GGAL211015C00007500 2021-07-27 13:31:46     7.5       1.15   0.95   1.65
# 2  GGAL211015C00010000 2021-07-29 19:17:39    10.0       0.26   0.20   0.25
# 3  GGAL211015C00012500 2021-07-29 15:15:13    12.5       0.08   0.00   0.50
# 4  GGAL211015C00015000 2021-07-09 15:51:34    15.0       0.10   0.00   0.10
# 0  GGAL220121C00002500 2021-07-08 18:27:09     2.5       5.70   5.20   5.80
# 1  GGAL220121C00005000 2021-07-29 19:10:54     5.0       3.32   2.60   3.50
# 2  GGAL220121C00007500 2021-07-27 16:11:10     7.5       1.45   1.10   1.60
# 3  GGAL220121C00010000 2021-07-29 19:42:03    10.0       0.60   0.45   0.60
# 4  GGAL220121C00012500 2021-07-29 19:10:54    12.5       0.20   0.15   0.25
# 5  GGAL220121C00015000 2021-07-29 19:02:04    15.0       0.10   0.05   0.35
# 6  GGAL220121C00017500 2021-07-07 18:38:01    17.5       0.07   0.00   0.40
# 7  GGAL220121C00020000 2021-07-29 16:13:56    20.0       0.10   0.00   0.50
# 8  GGAL220121C00022500 2021-06-25 17:15:02    22.5       0.05   0.00   0.75
# 0  GGAL230120C00002500 2021-06-03 14:04:02     2.5       7.25   4.30   7.50
# 1  GGAL230120C00005000 2021-07-20 13:36:54     5.0       3.50   2.60   5.10
# 2  GGAL230120C00007500 2021-07-19 16:51:53     7.5       2.25   2.00   2.45
# 3  GGAL230120C00010000 2021-07-29 19:53:14    10.0       1.50   1.15   1.55
# 4  GGAL230120C00012500 2021-07-27 16:45:35    12.5       0.93   0.85   1.00
# 4      REGULAR      USD   GGAL  8.08
# 5      REGULAR      USD   GGAL  8.08
# 6      REGULAR      USD   GGAL  8.08
# 7      REGULAR      USD   GGAL  8.08
# 8      REGULAR      USD   GGAL  8.08
# 0      REGULAR      USD   GGAL  8.08
# 1      REGULAR      USD   GGAL  8.08
# 2      REGULAR      USD   GGAL  8.08
# 3      REGULAR      USD   GGAL  8.08
# 4      REGULAR      USD   GGAL  8.08
# 5      REGULAR      USD   GGAL  8.08
# 6      REGULAR      USD   GGAL  8.08
# 7      REGULAR      USD   GGAL  8.08
# 0      REGULAR      USD   GGAL  8.08
# 1      REGULAR      USD   GGAL  8.08
# 2      REGULAR      USD   GGAL  8.08
# 0      REGULAR      USD   GGAL  8.08
# 1      REGULAR      USD   GGAL  8.08
# 0      REGULAR      USD   GGAL  8.08
# 1      REGULAR      USD   GGAL  8.08
# 2      REGULAR      USD   GGAL  8.08
# 3      REGULAR      USD   GGAL  8.08
# 4      REGULAR      USD   GGAL  8.08
# 0      REGULAR      USD   GGAL  8.08
# 1      REGULAR      USD   GGAL  8.08
# 2      REGULAR      USD   GGAL  8.08
# 3      REGULAR      USD   GGAL  8.08
# 4      REGULAR      USD   GGAL  8.08
# 5      REGULAR      USD   GGAL  8.08
# 6      REGULAR      USD   GGAL  8.08
# 7      REGULAR      USD   GGAL  8.08
# 8      REGULAR      USD   GGAL  8.08
# 0      REGULAR      USD   GGAL  8.08
# 1      REGULAR      USD   GGAL  8.08
# 2      REGULAR      USD   GGAL  8.08
# 3      REGULAR      USD   GGAL  8.08
# 4      REGULAR      USD   GGAL  8.08
# 5      REGULAR      USD   GGAL  8.08
# 6      REGULAR      USD   GGAL  8.08
# 7      REGULAR      USD   GGAL  8.08

# %%
panel_ociones_GGAL_nyse_clean = obtener_panel_opciones_nyse('GGAL', True)
panel_ociones_GGAL_nyse_clean
# Out:
#                 Especie Ticker  Spot CallPut  Strike  TTM   Last  Moneyness  \
# 0   GGAL210820C00005000   GGAL  8.08       C     5.0   21   4.30   1.616000
# 1   GGAL210820C00007500   GGAL  8.08       C     7.5   21   0.90   1.077333
# 2   GGAL210820P00007500   GGAL  8.08       P     7.5   21   0.20   1.077333
# 3   GGAL210820C00010000   GGAL  8.08       C    10.0   21   0.05   0.808000
# 4   GGAL210820P00010000   GGAL  8.08       P    10.0   21   2.10   0.808000
# 5   GGAL210820C00012500   GGAL  8.08       C    12.5   21   0.10   0.646400
# 6   GGAL210820P00012500   GGAL  8.08       P    12.5   21   4.00   0.646400
# 7   GGAL210917P00005000   GGAL  8.08       P     5.0   49   0.05   1.616000
# 8   GGAL210917C00007500   GGAL  8.08       C     7.5   49   1.10   1.077333
# 9   GGAL210917P00007500   GGAL  8.08       P     7.5   49   0.35   1.077333
# 10  GGAL210917C00010000   GGAL  8.08       C    10.0   49   0.20   0.808000
# 11  GGAL211015P00002500   GGAL  8.08       P     2.5   77   0.25   3.232000
# 12  GGAL211015C00005000   GGAL  8.08       C     5.0   77   5.10   1.616000
# 13  GGAL211015P00005000   GGAL  8.08       P     5.0   77   0.01   1.616000
# 14  GGAL211015C00007500   GGAL  8.08       C     7.5   77   1.15   1.077333
# 53  GGAL230120C00020000   GGAL  8.08       C    20.0  539   0.35   0.404000
# 54  GGAL230120P00020000   GGAL  8.08       P    20.0  539  13.93   0.404000
#
#     impliedVolatility    Ask    Bid
# 0            1.046880   3.10   2.50
# 1            0.515630   0.85   0.65
# 2            0.636722   0.25   0.00
# 3            0.531255   0.05   0.00
# 4            0.951172   2.40   1.85
# 5            1.625002   0.55   0.00
# 6            2.273442   5.10   3.70
# 7            0.984375   0.20   0.00
# 8            0.607426   1.20   0.85
# 9            0.519536   0.40   0.30
# 10           0.625004   0.20   0.00
# 11           1.296879   0.05   0.00
# 12           0.828127   3.30   3.10
# 13           0.789065   0.20   0.00
# 14           0.687503   1.65   0.95
# 15           0.508794   0.55   0.40
# 16           0.523442   0.25   0.20
# 17           0.571293   2.20   1.80
# 18           0.837892   0.50   0.00
# 19           0.621098   4.50   3.80
# 20           0.734378   0.10   0.00
# 21           1.394534   5.80   5.20
# 22           0.976563   0.10   0.00
# 23           0.841798   3.50   2.60
# 24           0.615238   0.35   0.00
# 25           0.601566   1.60   1.10
# 26           0.543950   0.90   0.25
# 27           0.506841   0.60   0.45
# 28           0.534184   2.50   2.15
# 29           0.521489   0.25   0.15
# 30           0.698245   4.90   4.10
# 31           0.658207   0.35   0.05
# 32           0.720706   7.20   6.70
# 33           0.765627   0.40   0.00
# 34           0.000010   0.00   0.00
# 35           0.898439   0.50   0.00
# 36           0.962891  12.80  11.70
# 37           1.076176   0.75   0.00
# 38           1.510745  16.90  14.20
# 39           0.896485   7.50   4.30
# 40           0.000000   5.00   0.00
# 41           0.635746   5.10   2.60
# 42           0.752932   1.70   0.40
# 43           0.516606   2.45   2.00
# 44           0.574711   1.85   0.50
# 45           0.505864   1.55   1.15
# 46           0.539555   5.50   1.30
# 47           0.527348   1.00   0.85
# 48           0.569340   7.70   3.30
# 49           0.555180   0.70   0.25
# 50           0.518560  10.00   5.00
# 51           0.533208   0.60   0.25
# 52           0.588383  12.40   7.60
# 53           0.578129   0.65   0.15
# 54           1.049321  16.40  11.50

# %% [markdown]
# ## 1) Modulo yfinance para Yahoo Finance

# %%
ticker = 'GGAL'
data = yf.Ticker(ticker)

#Data es un objeto
# data.info contiene informacion (mucha) del activo

data.info
# Out:
# {'zip': '1038',
#  'sector': 'Financial Services',
#  'fullTimeEmployees': 9271,
#  'longBusinessSummary': "Grupo Financiero Galicia S.A., a financial services holding company, provides various financial products and services to individuals and companies in Argentina. The company operates through Banks, Ecosistema NaranjaX, Insurance, and Other Businesses segments. The company's products and services cover savings, current, and checking accounts; personal loans; express and mortgage loans; credit and debit cards; and online banking services. It also offers financing products and services; consumer finance services; electronic check products and services; global custody services; Fima funds; financial and stock market services to individuals, companies, and financial institutions; foreign trade services; and capital market and investment banking products that include debt securities, short-term securities, letters, and financial trusts. In addition, the company provides home and life, and pet insurance, as well as technical insurance with multi-risk coverage for companies. As of December 31, 2020, it had 326 full service banking branches; 1,013 ATMs; and 1,095 self-service terminals. Grupo Financiero Galicia S.A. was founded in 1905 and is based in Buenos Aires, Argentina.",
#  'city': 'Buenos Aires',
#  'phone': '54 11 4343 7528',
#  'country': 'Argentina',
#  'companyOfficers': [],
#  'website': 'http://www.gfgsa.com',
#  'maxAge': 1,
#  'address1': 'Teniente General Juan D. PerOn 430',
#  'fax': '54 11 4343 7528',
#  'industry': 'Banks—Regional',
#  'address2': '25th Floor',
#  'ebitdaMargins': 0,
#  'profitMargins': 0.09575,
#  'grossMargins': 0,
#  'operatingCashflow': 121879674880,
#  'revenueGrowth': -0.095,
#  'operatingMargins': 0.19636999,
#  'ebitda': None,
#  'targetLowPrice': 5,
#  'recommendationKey': 'underperform',
#  'grossProfits': 180556365000,
#  'freeCashflow': None,
#  'targetMedianPrice': 8,
#  'currentPrice': 8.08,
#  'earningsGrowth': -0.816,
#  'currentRatio': None,
#  'returnOnAssets': 0.01774,
#  'numberOfAnalystOpinions': 7,
#  'targetMeanPrice': 7.71,
#  'debtToEquity': None,
#  'returnOnEquity': 0.10334,
#  'targetHighPrice': 9,
#  'totalCash': 313328861184,
#  'totalDebt': 141572751360,
#  'totalRevenue': 180650786816,
#  'totalCashPerShare': 2124.707,
#  'financialCurrency': 'ARS',
#  'revenuePerShare': 1241.82,
#  'quickRatio': None,
#  'recommendationMean': 3.6,
#  'exchange': 'NMS',
#  'shortName': 'Grupo Financiero Galicia S.A.',
#  'longName': 'Grupo Financiero Galicia S.A.',
#  'exchangeTimezoneName': 'America/New_York',
#  'exchangeTimezoneShortName': 'EDT',
#  'isEsgPopulated': False,
#  'gmtOffSetMilliseconds': '-14400000',
#  'quoteType': 'EQUITY',
#  'symbol': 'GGAL',
#  'messageBoardId': 'finmb_1532718',
#  'market': 'us_market',
#  'annualHoldingsTurnover': None,
#  'enterpriseToRevenue': -0.944,
#  'beta3Year': None,
#  'enterpriseToEbitda': None,
#  '52WeekChange': -0.31166667,
#  'morningStarRiskRating': None,
#  'forwardEps': 2.56,
#  'revenueQuarterlyGrowth': None,
#  'sharesOutstanding': 147468992,
#  'fundInceptionDate': None,
#  'annualReportExpenseRatio': None,
#  'totalAssets': None,
#  'bookValue': 1392.94,
#  'sharesShort': 1254351,
#  'sharesPercentSharesOut': 0.0085,
#  'fundFamily': None,
#  'lastFiscalYearEnd': 1609372800,
#  'heldPercentInstitutions': 0.08425,
#  'netIncomeToCommon': 17297162240,
#  'trailingEps': 1.23,
#  'lastDividendValue': 0.064,
#  'SandP52WeekChange': 0.34530067,
#  'priceToBook': 0.0058006807,
#  'heldPercentInsiders': 0.12616,
#  'nextFiscalYearEnd': 1672444800,
#  'yield': None,
#  'mostRecentQuarter': 1617148800,
#  'shortRatio': 1.8,
#  'sharesShortPreviousMonthDate': 1623715200,
#  'floatShares': 81877854,
#  'beta': 2.565116,
#  'enterpriseValue': -170538008576,
#  'priceHint': 2,
#  'threeYearAverageReturn': None,
#  'lastSplitDate': None,
#  'lastSplitFactor': None,
#  'legalType': None,
#  'lastDividendDate': 1620950400,
#  'morningStarOverallRating': None,
#  'earningsQuarterlyGrowth': -0.81,
#  'priceToSalesTrailing12Months': 0.01232377,
#  'dateShortInterest': 1626307200,
#  'pegRatio': -0.11,
#  'ytdReturn': None,
#  'forwardPE': 3.15625,
#  'lastCapGain': None,
#  'shortPercentOfFloat': None,
#  'sharesShortPriorMonth': 837982,
#  'impliedSharesOutstanding': None,
#  'category': None,
#  'fiveYearAverageReturn': None,
#  'previousClose': 8.26,
#  'regularMarketOpen': 8.28,
#  'twoHundredDayAverage': 8.17058,
#  'trailingAnnualDividendYield': 0.12312348,
#  'payoutRatio': 0.0537,
#  'volume24Hr': None,
#  'regularMarketDayHigh': 8.28,
#  'navPrice': None,
#  'averageDailyVolume10Day': 523842,
#  'regularMarketPreviousClose': 8.26,
#  'fiftyDayAverage': 8.865294,
#  'trailingAnnualDividendRate': 1.017,
#  'open': 8.28,
#  'toCurrency': None,
#  'averageVolume10days': 523842,
#  'expireDate': None,
#  'algorithm': None,
#  'dividendRate': 0.06,
#  'exDividendDate': 1620950400,
#  'circulatingSupply': None,
#  'startDate': None,
#  'regularMarketDayLow': 8.02,
#  'currency': 'USD',
#  'trailingPE': 6.5691056,
#  'regularMarketVolume': 807660,
#  'lastMarket': None,
#  'maxSupply': None,
#  'openInterest': None,
#  'marketCap': 2226298624,
#  'volumeAllCurrencies': None,
#  'strikePrice': None,
#  'averageVolume': 791848,
#  'dayLow': 8.02,
#  'ask': 8.08,
#  'askSize': 900,
#  'volume': 807660,
#  'fiftyTwoWeekHigh': 14.94,
#  'fromCurrency': None,
#  'fiveYearAvgDividendYield': None,
#  'fiftyTwoWeekLow': 5.86,
#  'bid': 8.04,
#  'tradeable': False,
#  'dividendYield': 0.0078,
#  'bidSize': 3200,
#  'dayHigh': 8.28,
#  'regularMarketPrice': 8.08,
#  'logo_url': 'https://logo.clearbit.com/gfgsa.com'}

# %%
# Spot price

hist = data.history()

spot = hist.tail(1)['Close'].iloc[0]
spot
# Out:
# 8.079999923706055

# %%
# Vencimientos de opciones
vencimientos = data.options

vencimientos
# Out:
# ('2021-08-20', '2021-09-17', '2021-10-15', '2022-01-21', '2023-01-20')

# %%
# Calls y puts
calls = data.option_chain(vencimientos[0])[0]
puts = data.option_chain(vencimientos[0])[1]

puts
# Out:
#         contractSymbol       lastTradeDate  strike  lastPrice   bid   ask  \
# 0  GGAL210820P00007500 2021-07-23 18:51:48     7.5        0.2  0.00  0.25
# 1  GGAL210820P00010000 2021-07-19 16:39:39    10.0        2.1  1.85  2.40
# 2  GGAL210820P00012500 2021-07-02 19:30:41    12.5        4.0  3.70  5.10
#
#    change  percentChange  volume  openInterest  impliedVolatility  inTheMoney  \
# 0     0.0            0.0     100           341           0.636722       False
# 1     0.0            0.0       1            10           0.951172        True
# 2     0.0            0.0      10            10           2.273442        True
#
#   contractSize currency
# 0      REGULAR      USD
# 1      REGULAR      USD
# 2      REGULAR      USD

# %% [markdown]
# ### Que hace internamente el metodo??

# %%
#Recorro cada vencimiento disponible y voy tomando calls por un lado y puts por otro
for vencimiento in vencimientos[1:]:
        calls = calls.append(data.option_chain(vencimiento)[0])
        puts = puts.append(data.option_chain(vencimiento)[1])

#Uno los puts y los calls
panel_opciones = calls.append(puts)

# Le agrego dos columnas utiles - Ticker y Spot

panel_opciones['Spot'] = hist.tail(1)['Close'].iloc[0]
panel_opciones['Ticker'] = ticker

panel_opciones.head(10)
# Out:
#         contractSymbol       lastTradeDate  strike  lastPrice   bid   ask  \
# 0  GGAL210820C00005000 2021-06-25 15:09:02     5.0       4.30  2.50  3.10
# 1  GGAL210820C00007500 2021-07-29 17:55:17     7.5       0.90  0.65  0.85
# 2  GGAL210820C00010000 2021-07-27 19:42:51    10.0       0.05  0.00  0.05
# 3  GGAL210820C00012500 2021-06-23 17:18:27    12.5       0.10  0.00  0.55
# 0  GGAL210917C00007500 2021-07-28 18:40:40     7.5       1.10  0.85  1.20
# 1  GGAL210917C00010000 2021-07-21 19:09:36    10.0       0.20  0.00  0.20
# 0  GGAL211015C00005000 2021-06-08 14:49:02     5.0       5.10  3.10  3.30
# 1  GGAL211015C00007500 2021-07-27 13:31:46     7.5       1.15  0.95  1.65
# 2  GGAL211015C00010000 2021-07-29 19:17:39    10.0       0.26  0.20  0.25
# 3  GGAL211015C00012500 2021-07-29 15:15:13    12.5       0.08  0.00  0.50
#
#    change  percentChange  volume  openInterest  impliedVolatility  inTheMoney  \
# 0    0.00       0.000000     1.0             1           1.046880        True
# 1    0.00       0.000000    10.0            95           0.515630        True
# 2    0.00       0.000000     1.0            38           0.531255       False
# 3    0.00       0.000000     NaN             1           1.625002       False
# 0    0.00       0.000000     5.0            91           0.607426        True
# 1    0.00       0.000000    30.0            83           0.625004       False
# 0    0.00       0.000000     1.0             1           0.828127        True
# 1    0.00       0.000000     3.0           336           0.687503        True
# 2    0.01       3.999996    11.0          1744           0.523442       False
# 3   -0.02     -20.000004    10.0          1393           0.837892       False
#
#   contractSize currency  Spot Ticker
# 0      REGULAR      USD  8.08   GGAL
# 1      REGULAR      USD  8.08   GGAL
# 2      REGULAR      USD  8.08   GGAL
# 3      REGULAR      USD  8.08   GGAL
# 0      REGULAR      USD  8.08   GGAL
# 1      REGULAR      USD  8.08   GGAL
# 0      REGULAR      USD  8.08   GGAL
# 1      REGULAR      USD  8.08   GGAL
# 2      REGULAR      USD  8.08   GGAL
# 3      REGULAR      USD  8.08   GGAL

# %% [markdown]
# ## Del panel de Yahoo crudo a otro con informacion customizada (igual que antes)

# %% [markdown]
# #### *) Agrego columnas utiles

# %%
panel_opciones['Moneyness'] = 0.0
panel_opciones['TTM'] = 0
panel_opciones['CallPut'] = ''
panel_opciones = panel_opciones.reset_index()

panel_opciones.head(5)
# Out:
#    index       contractSymbol       lastTradeDate  strike  lastPrice   bid  \
# 0      0  GGAL210820C00005000 2021-06-25 15:09:02     5.0       4.30  2.50
# 1      1  GGAL210820C00007500 2021-07-29 17:55:17     7.5       0.90  0.65
# 2      2  GGAL210820C00010000 2021-07-27 19:42:51    10.0       0.05  0.00
# 3      3  GGAL210820C00012500 2021-06-23 17:18:27    12.5       0.10  0.00
# 4      0  GGAL210917C00007500 2021-07-28 18:40:40     7.5       1.10  0.85
#
#     ask  change  percentChange  volume  openInterest  impliedVolatility  \
# 0  3.10     0.0            0.0     1.0             1           1.046880
# 1  0.85     0.0            0.0    10.0            95           0.515630
# 2  0.05     0.0            0.0     1.0            38           0.531255
# 3  0.55     0.0            0.0     NaN             1           1.625002
# 4  1.20     0.0            0.0     5.0            91           0.607426
#
#    inTheMoney contractSize currency  Spot Ticker  Moneyness  TTM CallPut
# 0        True      REGULAR      USD  8.08   GGAL        0.0    0
# 1        True      REGULAR      USD  8.08   GGAL        0.0    0
# 2       False      REGULAR      USD  8.08   GGAL        0.0    0
# 3       False      REGULAR      USD  8.08   GGAL        0.0    0
# 4        True      REGULAR      USD  8.08   GGAL        0.0    0

# %% [markdown]
# #### *) Recorro las filas (1ra como ejemplo)

# %%
idx = panel_opciones.index.values[0]

# %%
callput = panel_opciones.contractSymbol.values[idx][10:11]
panel_opciones['CallPut'].values[idx] = callput

# %%
year = 2000 + int(panel_opciones.contractSymbol.values[idx][4:6])
month = int(panel_opciones.contractSymbol.values[idx][6:8])
day = int(panel_opciones.contractSymbol.values[idx][8:10])

hoy = datetime.date.today()
expiry_datetime = datetime.date(year, month, day)
ttm = (expiry_datetime - hoy).days

panel_opciones['TTM'].values[idx] = ttm

# %%
panel_opciones['Moneyness'].values[idx] = panel_opciones['Spot'].values[idx] / panel_opciones['strike'].values[idx]

# %%
panel_opciones.head(2)
# Out:
#    index       contractSymbol       lastTradeDate  strike  lastPrice   bid  \
# 0      0  GGAL210820C00005000 2021-06-25 15:09:02     5.0        4.3  2.50
# 1      1  GGAL210820C00007500 2021-07-29 17:55:17     7.5        0.9  0.65
#
#     ask  change  percentChange  volume  openInterest  impliedVolatility  \
# 0  3.10     0.0            0.0     1.0             1            1.04688
# 1  0.85     0.0            0.0    10.0            95            0.51563
#
#    inTheMoney contractSize currency  Spot Ticker  Moneyness  TTM CallPut
# 0        True      REGULAR      USD  8.08   GGAL      1.616   21       C
# 1        True      REGULAR      USD  8.08   GGAL      0.000    0

# %% [markdown]
# #### *) Recorro las filas (las restantes como ejemplo)

# %%
for idx in list(panel_opciones.index.values[1:]):
        year = 2000 + int(panel_opciones.contractSymbol.values[idx][4:6])
        month = int(panel_opciones.contractSymbol.values[idx][6:8])
        day = int(panel_opciones.contractSymbol.values[idx][8:10])
        
        hoy = datetime.date.today()
        expiry_datetime = datetime.date(year, month, day)
        ttm = (expiry_datetime - hoy).days

        panel_opciones['TTM'].values[idx] = ttm
        callput = panel_opciones.contractSymbol.values[idx][10:11]
        panel_opciones['CallPut'].values[idx] = callput
        
panel_opciones.Moneyness = panel_opciones.Spot/ panel_opciones.strike

# %%
panel_opciones.head(10)
# Out:
#    index       contractSymbol       lastTradeDate  strike  lastPrice   bid  \
# 0      0  GGAL210820C00005000 2021-06-25 15:09:02     5.0       4.30  2.50
# 1      1  GGAL210820C00007500 2021-07-29 17:55:17     7.5       0.90  0.65
# 2      2  GGAL210820C00010000 2021-07-27 19:42:51    10.0       0.05  0.00
# 3      3  GGAL210820C00012500 2021-06-23 17:18:27    12.5       0.10  0.00
# 4      0  GGAL210917C00007500 2021-07-28 18:40:40     7.5       1.10  0.85
# 5      1  GGAL210917C00010000 2021-07-21 19:09:36    10.0       0.20  0.00
# 6      0  GGAL211015C00005000 2021-06-08 14:49:02     5.0       5.10  3.10
# 7      1  GGAL211015C00007500 2021-07-27 13:31:46     7.5       1.15  0.95
# 8      2  GGAL211015C00010000 2021-07-29 19:17:39    10.0       0.26  0.20
# 9      3  GGAL211015C00012500 2021-07-29 15:15:13    12.5       0.08  0.00
#
#     ask  change  percentChange  volume  openInterest  impliedVolatility  \
# 0  3.10    0.00       0.000000     1.0             1           1.046880
# 1  0.85    0.00       0.000000    10.0            95           0.515630
# 2  0.05    0.00       0.000000     1.0            38           0.531255
# 3  0.55    0.00       0.000000     NaN             1           1.625002
# 4  1.20    0.00       0.000000     5.0            91           0.607426
# 5  0.20    0.00       0.000000    30.0            83           0.625004
# 6  3.30    0.00       0.000000     1.0             1           0.828127
# 7  1.65    0.00       0.000000     3.0           336           0.687503
# 8  0.25    0.01       3.999996    11.0          1744           0.523442
# 9  0.50   -0.02     -20.000004    10.0          1393           0.837892
#
#    inTheMoney contractSize currency  Spot Ticker  Moneyness  TTM CallPut
# 0        True      REGULAR      USD  8.08   GGAL   1.616000   21       C
# 1        True      REGULAR      USD  8.08   GGAL   1.077333   21       C
# 2       False      REGULAR      USD  8.08   GGAL   0.808000   21       C
# 3       False      REGULAR      USD  8.08   GGAL   0.646400   21       C
# 4        True      REGULAR      USD  8.08   GGAL   1.077333   49       C
# 5       False      REGULAR      USD  8.08   GGAL   0.808000   49       C
# 6        True      REGULAR      USD  8.08   GGAL   1.616000   77       C
# 7        True      REGULAR      USD  8.08   GGAL   1.077333   77       C
# 8       False      REGULAR      USD  8.08   GGAL   0.808000   77       C
# 9       False      REGULAR      USD  8.08   GGAL   0.646400   77       C

# %% [markdown]
# #### Panel Limpio

# %%
panel_opciones = panel_opciones.rename(
            columns={'lastTradeDate': 'Last_Date', 'contractSymbol': 'Especie', 'strike': 'Strike', 'bid': 'Bid',
                     'ask': 'Ask', 'lastPrice': 'Last'}, inplace=False)

panel_opciones = panel_opciones.sort_values(['TTM', 'Ticker', 'Strike', 'CallPut'])

panel_opciones = panel_opciones[['Especie', 'Ticker', 'Spot', 'CallPut', 'Strike', 'TTM', 'Last', 'Bid','Ask','impliedVolatility','Moneyness']]

# %%
panel_opciones = panel_opciones.reset_index()
del panel_opciones['index']
panel_opciones
# Out:
#                 Especie Ticker  Spot CallPut  Strike  TTM   Last    Bid  \
# 0   GGAL210820C00005000   GGAL  8.08       C     5.0   21   4.30   2.50
# 1   GGAL210820C00007500   GGAL  8.08       C     7.5   21   0.90   0.65
# 2   GGAL210820P00007500   GGAL  8.08       P     7.5   21   0.20   0.00
# 3   GGAL210820C00010000   GGAL  8.08       C    10.0   21   0.05   0.00
# 4   GGAL210820P00010000   GGAL  8.08       P    10.0   21   2.10   1.85
# 5   GGAL210820C00012500   GGAL  8.08       C    12.5   21   0.10   0.00
# 6   GGAL210820P00012500   GGAL  8.08       P    12.5   21   4.00   3.70
# 7   GGAL210917P00005000   GGAL  8.08       P     5.0   49   0.05   0.00
# 8   GGAL210917C00007500   GGAL  8.08       C     7.5   49   1.10   0.85
# 9   GGAL210917P00007500   GGAL  8.08       P     7.5   49   0.35   0.30
# 10  GGAL210917C00010000   GGAL  8.08       C    10.0   49   0.20   0.00
# 50  GGAL230120P00015000   GGAL  8.08       P    15.0  539   6.51   5.00
# 51  GGAL230120C00017500   GGAL  8.08       C    17.5  539   0.40   0.25
# 52  GGAL230120P00017500   GGAL  8.08       P    17.5  539  11.75   7.60
# 53  GGAL230120C00020000   GGAL  8.08       C    20.0  539   0.35   0.15
# 54  GGAL230120P00020000   GGAL  8.08       P    20.0  539  13.93  11.50
#
#       Ask  impliedVolatility  Moneyness
# 0    3.10           1.046880   1.616000
# 1    0.85           0.515630   1.077333
# 2    0.25           0.636722   1.077333
# 3    0.05           0.531255   0.808000
# 4    2.40           0.951172   0.808000
# 5    0.55           1.625002   0.646400
# 6    5.10           2.273442   0.646400
# 7    0.20           0.984375   1.616000
# 8    1.20           0.607426   1.077333
# 9    0.40           0.519536   1.077333
# 10   0.20           0.625004   0.808000
# 11   0.05           1.296879   3.232000
# 12   3.30           0.828127   1.616000
# 13   0.20           0.789065   1.616000
# 14   1.65           0.687503   1.077333
# 15   0.55           0.508794   1.077333
# 16   0.25           0.523442   0.808000
# 17   2.20           0.571293   0.808000
# 18   0.50           0.837892   0.646400
# 19   4.50           0.621098   0.646400
# 20   0.10           0.734378   0.538667
# 21   5.80           1.394534   3.232000
# 22   0.10           0.976563   3.232000
# 23   3.50           0.841798   1.616000
# 24   0.35           0.615238   1.616000
# 25   1.60           0.601566   1.077333
# 26   0.90           0.543950   1.077333
# 27   0.60           0.506841   0.808000
# 28   2.50           0.534184   0.808000
# 29   0.25           0.521489   0.646400
# 30   4.90           0.698245   0.646400
# 31   0.35           0.658207   0.538667
# 32   7.20           0.720706   0.538667
# 33   0.40           0.765627   0.461714
# 34   0.00           0.000010   0.461714
# 35   0.50           0.898439   0.404000
# 36  12.80           0.962891   0.404000
# 37   0.75           1.076176   0.359111
# 38  16.90           1.510745   0.359111
# 39   7.50           0.896485   3.232000
# 40   5.00           0.000000   3.232000
# 41   5.10           0.635746   1.616000
# 42   1.70           0.752932   1.616000
# 43   2.45           0.516606   1.077333
# 44   1.85           0.574711   1.077333
# 45   1.55           0.505864   0.808000
# 46   5.50           0.539555   0.808000
# 47   1.00           0.527348   0.646400
# 48   7.70           0.569340   0.646400
# 49   0.70           0.555180   0.538667
# 50  10.00           0.518560   0.538667
# 51   0.60           0.533208   0.461714
# 52  12.40           0.588383   0.461714
# 53   0.65           0.578129   0.404000
# 54  16.40           1.049321   0.404000

# %% [markdown]
# ## 2) Ploteando los datos

# %% [markdown]
# ### Para cada vencimiento, grafico los strikes

# %%
# NYSE
panel_opciones_ggal_nyse_limpio = obtener_panel_opciones_nyse('GGAL', True)

TTMs = list(set(panel_opciones_ggal_nyse_limpio.TTM.values))
TTMs
# Out:
# [77, 175, 49, 21, 539]

# %%
TTM = 8
panel_opciones_ggal_nyse_limpio[(panel_opciones_ggal_nyse_limpio.TTM == TTM) & (panel_opciones_ggal_nyse_limpio.CallPut == "C")].head(10)
# Out:
# Empty DataFrame
# Columns: [Especie, Ticker, Spot, CallPut, Strike, TTM, Last, Moneyness, impliedVolatility, Ask, Bid]
# Index: []

# %%
from matplotlib import pyplot as plt
CP = "C"
for TTM in TTMs:
    Ks = panel_opciones_ggal_nyse_limpio[(panel_opciones_ggal_nyse_limpio.TTM == TTM) & (panel_opciones_ggal_nyse_limpio.CallPut == CP)].Strike.values
    precios = panel_opciones_ggal_nyse_limpio[(panel_opciones_ggal_nyse_limpio.TTM == TTM) & (panel_opciones_ggal_nyse_limpio.CallPut == CP)].Last.values
    ## Last VS (B+A)/2
    plt.plot(Ks, precios,'*', label='TTM = '+str(TTM))


plt.legend()

plt.xlabel('Strike')
plt.ylabel('Precio de mercado del Call')
plt.title('Precio de mercado de las opciones Call con respecto al Strike')
    
plt.show()

# %%
CP = "P"
for TTM in TTMs:
    Ks = panel_opciones_ggal_nyse_limpio[(panel_opciones_ggal_nyse_limpio.TTM == TTM) & (panel_opciones_ggal_nyse_limpio.CallPut == CP)].Strike.values
    precios = panel_opciones_ggal_nyse_limpio[(panel_opciones_ggal_nyse_limpio.TTM == TTM) & (panel_opciones_ggal_nyse_limpio.CallPut == CP)].Last.values
    plt.plot(Ks, precios,'*', label='TTM = '+str(TTM))


plt.legend()

plt.xlabel('Strike')
plt.ylabel('Precio de mercado del Call')
plt.title('Precio de mercado de las opciones Call con respecto al Strike')
    
plt.show()

# %% [markdown]
# ### Para cada strike, grafico los TTM

# %%
Ks = list(set(panel_opciones_ggal_nyse_limpio.Strike.values))

# %%
from matplotlib import pyplot as plt
CP = "C"
for K in Ks:
    TTMs = panel_opciones_ggal_nyse_limpio[(panel_opciones_ggal_nyse_limpio.Strike == K) & (panel_opciones_ggal_nyse_limpio.CallPut == CP)].TTM.values
    precios = panel_opciones_ggal_nyse_limpio[(panel_opciones_ggal_nyse_limpio.Strike == K) & (panel_opciones_ggal_nyse_limpio.CallPut == CP)].Last.values
    if len(TTMs)>1:
        plt.plot(TTMs, precios,'*', label='Strike = '+str(K))

plt.legend()

plt.xlabel('TTM')
plt.ylabel('Precio de mercado del Call')
plt.title('Precio de mercado de las opciones Call con respecto al TTM')
    
plt.show()

# %% [markdown]
# ## Ploteando los datos con un ticker mega liquido

# %%
# NYSE AAPL
ticker = 'TSLA'
panel_opciones_nyse_limpio = obtener_panel_opciones_nyse(ticker, True)

TTMs = list(set(panel_opciones_nyse_limpio.TTM.values))
TTMs.sort()
TTMs
# Out:
# [0, 7, 14, 21, 28, 35, 49, 77, 112, 140, 175, 231, 322, 413, 539, 595, 686]

# %%
from matplotlib import pyplot as plt
CP = "C"
for TTM in TTMs[2:5]:
    Ks = panel_opciones_nyse_limpio[(panel_opciones_nyse_limpio.TTM == TTM) & (panel_opciones_nyse_limpio.CallPut == CP)].Strike.values
    precios = panel_opciones_nyse_limpio[(panel_opciones_nyse_limpio.TTM == TTM) & (panel_opciones_nyse_limpio.CallPut == CP)].Last.values
    plt.plot(Ks, precios, '.',label='TTM = '+str(TTM))


plt.legend()

plt.xlabel('Strike')
plt.ylabel('Precio de mercado del Call')
plt.title('Precio de mercado de las opciones Call con respecto al Strike')
    
plt.show()

# %%
TTMs[8:11]
# Out:
# [112, 140, 175]

# %%
from matplotlib import pyplot as plt
CP = "C"
for TTM in TTMs[8:11]:
    Ks = panel_opciones_nyse_limpio[(panel_opciones_nyse_limpio.TTM == TTM) & (panel_opciones_nyse_limpio.CallPut == CP)].Strike.values
    precios = panel_opciones_nyse_limpio[(panel_opciones_nyse_limpio.TTM == TTM) & (panel_opciones_nyse_limpio.CallPut == CP)].Last.values
    plt.plot(Ks, precios, '.',label='TTM = '+str(TTM))


plt.legend()

plt.xlabel('Strike')
plt.ylabel('Precio de mercado del Call')
plt.title('Precio de mercado de las opciones Call con respecto al Strike')
    
plt.show()

# %%
from matplotlib import pyplot as plt
CP = "C"
for TTM in TTMs[2:5]:
    Ks = panel_opciones_nyse_limpio[(panel_opciones_nyse_limpio.TTM == TTM) & (panel_opciones_nyse_limpio.CallPut == CP)].Strike.values
    precios = panel_opciones_nyse_limpio[(panel_opciones_nyse_limpio.TTM == TTM) & (panel_opciones_nyse_limpio.CallPut == CP)].Last.values
    plt.plot(Ks, precios,'.',label='TTM = '+str(TTM))


plt.legend()

plt.xlabel('Strike')
plt.ylabel('Precio de mercado del Call')
plt.title('Precio de mercado de las opciones Call con respecto al Strike')
    
plt.show()

# %%
TTMs[3:6]
# Out:
# [21, 28, 35]

# %%
from matplotlib import pyplot as plt
CP = "P"
for TTM in TTMs[3:6]:
    Ks = panel_opciones_nyse_limpio[(panel_opciones_nyse_limpio.TTM == TTM) & (panel_opciones_nyse_limpio.CallPut == CP)].Strike.values
    precios = panel_opciones_nyse_limpio[(panel_opciones_nyse_limpio.TTM == TTM) & (panel_opciones_nyse_limpio.CallPut == CP)].Last.values
    plt.plot(Ks, precios, '.',label='TTM = '+str(TTM))


plt.legend()

plt.xlabel('Strike')
plt.ylabel('Precio de mercado del Put')
plt.title('Precio de mercado de las opciones Put con respecto al Strike')
    
plt.show()

# %%
 TTMs[10:15]
# Out:
# [175, 231, 322, 413, 539]

# %%
from matplotlib import pyplot as plt
CP = "P"
for TTM in TTMs[10:15]:
    Ks = panel_opciones_nyse_limpio[(panel_opciones_nyse_limpio.TTM == TTM) & (panel_opciones_nyse_limpio.CallPut == CP)].Strike.values
    precios = panel_opciones_nyse_limpio[(panel_opciones_nyse_limpio.TTM == TTM) & (panel_opciones_nyse_limpio.CallPut == CP)].Last.values
    plt.plot(Ks, precios, '.',label='TTM = '+str(TTM))


plt.legend()

plt.xlabel('Strike')
plt.ylabel('Precio de mercado del Put')
plt.title('Precio de mercado de las opciones Put con respecto al Strike')
    
plt.show()

# %%
from matplotlib import pyplot as plt
CP = "P"
for TTM in TTMs[11:17]:
    Ks = panel_opciones_nyse_limpio[(panel_opciones_nyse_limpio.TTM == TTM) & (panel_opciones_nyse_limpio.CallPut == CP)].Strike.values
    precios = panel_opciones_nyse_limpio[(panel_opciones_nyse_limpio.TTM == TTM) & (panel_opciones_nyse_limpio.CallPut == CP)].Last.values
    plt.plot(Ks, precios, '.',label='TTM = '+str(TTM))


plt.legend()

plt.xlabel('Strike')
plt.ylabel('Precio de mercado del Put')
plt.title('Precio de mercado de las opciones Put con respecto al Strike')
    
plt.show()

# %%
Ks = list(set(panel_opciones_nyse_limpio.Strike.values))
Ks.sort()
len(Ks)
# Out:
# 660

# %%
from matplotlib import pyplot as plt
CP = "C"
for K in Ks[45:55]:
    TTMs = panel_opciones_nyse_limpio[(panel_opciones_nyse_limpio.Strike == K) & (panel_opciones_nyse_limpio.CallPut == CP)].TTM.values
    precios = panel_opciones_nyse_limpio[(panel_opciones_nyse_limpio.Strike == K) & (panel_opciones_nyse_limpio.CallPut == CP)].Last.values
    if len(TTMs)>1:
        plt.plot(TTMs, precios,'*', label='Strike = '+str(K))

plt.legend()

plt.xlabel('TTM')
plt.ylabel('Precio de mercado del Call')
plt.title('Precio de mercado de las opciones Call con respecto al TTM')
    
plt.show()

# %%
from matplotlib import pyplot as plt
CP = "P"
for K in Ks[100:]:
    TTMs = panel_opciones_nyse_limpio[(panel_opciones_nyse_limpio.Strike == K) & (panel_opciones_nyse_limpio.CallPut == CP)].Strike.values
    precios = panel_opciones_nyse_limpio[(panel_opciones_nyse_limpio.Strike == K) & (panel_opciones_nyse_limpio.CallPut == CP)].Last.values
    if len(TTMs)>1:
        plt.plot(TTMs, precios,'*', label='Strike = '+str(K))

plt.legend()

plt.xlabel('TTM')
plt.ylabel('Precio de mercado del Put')
plt.title('Precio de mercado de las opciones Put con respecto al TTM')
    
plt.show()

# %% [markdown]
# ## Pasar a Excel

# %%
panel_opciones_ggal_nyse_crudo = obtener_panel_opciones_nyse('GGAL', False)
panel_opciones_ggal_nyse_crudo.to_excel('Clase_2_panel_opciones_ggal_nyse_crudo.xls')

panel_opciones_ggal_nyse_limpio = obtener_panel_opciones_nyse('GGAL', True)
panel_opciones_ggal_nyse_limpio.to_excel('Clase_2_panel_opciones_ggal_nyse_limpio.xls')


panel_opciones_aapl_nyse_limpio = obtener_panel_opciones_nyse('AAPL', True)
panel_opciones_aapl_nyse_limpio.to_excel('Clase_2_panel_opciones_aapl_nyse_limpio.xls')
# Out:
# <ipython-input-35-22d6e1261356>:2: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   panel_opciones_ggal_nyse_crudo.to_excel('Clase_2_panel_opciones_ggal_nyse_crudo.xls')
# <ipython-input-35-22d6e1261356>:5: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   panel_opciones_ggal_nyse_limpio.to_excel('Clase_2_panel_opciones_ggal_nyse_limpio.xls')
# <ipython-input-35-22d6e1261356>:9: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   panel_opciones_aapl_nyse_limpio.to_excel('Clase_2_panel_opciones_aapl_nyse_limpio.xls')

# %% [markdown]
# ## 3) Payoffs y Estrategias

# %%
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# ### Vanilla Call y Put

# %%
def payoff_call(S,K):
    return np.maximum(S-K,0)

def payoff_put(S,K):
    return np.maximum(K-S,0)

# %%
K=50
S = np.linspace(0,100,50)

# %%
#Grafico la call

plt.plot(S,payoff_call(S, K))
plt.show()

# %%
#Grafico la put
plt.plot(S,payoff_put(S, K))
plt.show()

# %% [markdown]
# ### Forward sintetico y Combo

# %%
def payoff_forwardSintetico(S,K):
    return payoff_call(S,K)-payoff_put(S, K)

def payoff_combo(S,K1,K2):
    return payoff_call(S,K2)-payoff_put(S, K1)

# %%
#Grafico el forward sintetico
plt.plot(S,payoff_forwardSintetico(S, K))
plt.show()

# %%
K1 = 35
K2 = 65
#Grafico el combo
plt.plot(S,payoff_combo(S, K1,K2))
plt.show()

# %% [markdown]
# ### Spreads

# %%
def payoff_BullCS(S,K1,K2):
    return payoff_call(S,K1)-payoff_call(S, K2)

def payoff_BearCS(S,K1,K2):
    return payoff_call(S,K2)-payoff_call(S, K1)

def payoff_BullPS(S,K1,K2):
    return payoff_put(S,K1)-payoff_put(S, K2)


def payoff_BearPS(S,K1,K2):
    return payoff_put(S,K2)-payoff_put(S, K1)

# %%
#Grafico el Bull Call Spread
plt.plot(S,payoff_BullCS(S, K1, K2))
plt.show()

# %%
#Grafico el Bear Call Spread
plt.plot(S,payoff_BearCS(S, K1, K2))
plt.show()

# %%
#Grafico el Bull Put Spread
plt.plot(S,payoff_BullPS(S, K1, K2))
plt.show()

# %%
#Grafico el Bear Put Spread
plt.plot(S,payoff_BearPS(S, K1, K2))
plt.show()

# %% [markdown]
# ### Butterfly spreads

# %%
def payoff_CButterflyS(S,K1,K2,K3):
    return payoff_call(S,K1)-2*payoff_call(S, K2)+payoff_call(S, K3)

def payoff_PButterflyS(S,K1,K2,K3):
    return payoff_put(S,K1)-2*payoff_put(S, K2)+payoff_put(S, K3)

# %%
K1=35
K2=50
K3=65

# %%
#Grafico el Call Buterfly Spread
plt.plot(S,payoff_CButterflyS(S, K1, K2,K3))
plt.show()

# %%
#Grafico el Put Buterfly Spread
plt.plot(S,payoff_PButterflyS(S, K1, K2,K3))
plt.show()

# %% [markdown]
# ### Straddle y Strangle

# %%
def payoff_straddle(S,K):
    return payoff_call(S,K)+payoff_put(S, K)


def payoff_strangle(S,K1,K2):
    return payoff_call(S,K1)+payoff_put(S, K2)

# %%
K1 = 35
K2 = 65

# %%
#Grafico el Strangle
plt.plot(S,payoff_strangle(S, K1,K2))
plt.show()

# %%
#Grafico el Straddle

plt.plot(S,payoff_straddle(S, K))
plt.show()

# %% [markdown]
# ### Estrategia AD hoc - Iron Condor

# %%
def payoff_iron_condor(S,K1,K2,K3,K4):
    return payoff_put(S,K1)-payoff_put(S, K2)-payoff_call(S,K3)+payoff_call(S,K4)

# %%
K1 = 30
K2 = 45
K3 = 55
K4 = 70

# %%
plt.plot(S,payoff_iron_condor(S, K1,K2,K3,K4))
plt.show()

# %%
#usando el script con los metodos
import payoffs
payoffs.payoff_call(100,50)
